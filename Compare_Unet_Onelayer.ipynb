# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader  # Load the data
from torch.utils.tensorboard import SummaryWriter  # Show the Tensorboard
import cv2
import os
from matplotlib import pyplot as plt
from glob import glob
import random
import numpy as np
from math import ceil

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
def show_image_mask(img, mask, cmap='gray'):  # visualisation
    fig = plt.figure(figsize=(5, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(img, cmap=cmap)
    plt.axis('off')
    plt.subplot(1, 2, 2)
    plt.imshow(mask, cmap=cmap)
    plt.axis('off')
data_dir = '/content/drive/My Drive/data/train'
image = cv2.imread(os.path.join(data_dir,'image','cmr1.png'), cv2.IMREAD_UNCHANGED)
mask = cv2.imread(os.path.join(data_dir,'mask','cmr1_mask.png'), cv2.IMREAD_UNCHANGED)
show_image_mask(image, mask, cmap='gray')
plt.pause(1)
cv2.imwrite(os.path.join('./','cmr1.png'), mask*85)
# Out:
# True

# %% [markdown]
# # **1 DataImport**

# %%
################################################################################
class TrainDataset(data.Dataset):
    def __init__(self, root=''):
        super(TrainDataset, self).__init__()
        self.img_files = glob(os.path.join(root, 'image', '*.png'))
        self.mask_files = []
        for img_path in self.img_files:
            basename = os.path.basename(img_path)
            self.mask_files.append(os.path.join(root, 'mask', basename[:-4] + '_mask.png'))

    def __getitem__(self, index):
        img_path = self.img_files[index]
        mask_path = self.mask_files[index]
        data = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
        label = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)
        return torch.from_numpy(data).float(), torch.from_numpy(label).float()

    def __len__(self):
        return len(self.img_files)


class TestDataset(data.Dataset):
    def __init__(self, root=''):
        super(TestDataset, self).__init__()
        self.img_files = glob(os.path.join(root, 'image', '*.png'))

    def __getitem__(self, index):
        img_path = self.img_files[index]
        data = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
        return torch.from_numpy(data).float()

    def __len__(self):
        return len(self.img_files)
################################################################################

# %% [markdown]
# # **2 CNN Structure**

# %%
class EncoderLayer(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=False):
        super(EncoderLayer, self).__init__()
        layers = [
            nn.Conv2d(in_channels, out_channels, kernel_size=3,padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        ]
        if dropout:
            layers.append(nn.Dropout())
        layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
        self.encode = nn.Sequential(*layers)

    def forward(self, x):
        return self.encode(x)


class DecoderLayer(nn.Module):
    def __init__(self, in_channels, middle_channels, out_channels):
        super(DecoderLayer, self).__init__()
        self.decode = nn.Sequential(
            nn.Conv2d(in_channels, middle_channels, kernel_size=3,padding=1),
            nn.BatchNorm2d(middle_channels),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(middle_channels, out_channels, kernel_size=2, stride=2),
        )

    def forward(self, x):
        return self.decode(x)


def initialize_weights(*models):
    for model in models:
        for module in model.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight)
                if module.bias is not None:
                    module.bias.data.zero_()
            elif isinstance(module, nn.BatchNorm2d):
                module.weight.data.fill_(1)
                module.bias.data.zero_()


class UNet_onelayer(nn.Module):
    def __init__(self, num_classes):
        super(UNet_onelayer, self).__init__()
        self.enc1 = EncoderLayer(1, 64)
        self.enc2 = EncoderLayer(64, 128)
        self.enc3 = EncoderLayer(128, 256)
        self.enc4 = EncoderLayer(256, 512, dropout=True)
        self.center = DecoderLayer(512, 1024, 512)
        self.dec4 = DecoderLayer(1024, 512, 256)
        self.dec3 = DecoderLayer(512, 256, 128)
        self.dec2 = DecoderLayer(256, 128, 64)
        self.dec1 = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
        )
        self.final = nn.Conv2d(64, num_classes, kernel_size=1)
        initialize_weights(self)

    def forward(self, x):
        enc1 = self.enc1(x)
        enc2 = self.enc2(enc1)
        enc3 = self.enc3(enc2)
        enc4 = self.enc4(enc3)
        center = self.center(enc4)
        dec4 = self.dec4(torch.cat([center, F.upsample(enc4, center.size()[2:], mode='bilinear',align_corners=True)], 1))
        dec3 = self.dec3(torch.cat([dec4, F.upsample(enc3, dec4.size()[2:], mode='bilinear',align_corners=True)], 1))
        dec2 = self.dec2(torch.cat([dec3, F.upsample(enc2, dec3.size()[2:], mode='bilinear',align_corners=True)], 1))
        dec1 = self.dec1(torch.cat([dec2, F.upsample(enc1, dec2.size()[2:], mode='bilinear',align_corners=True)], 1))
        final = self.final(dec1)
        return F.upsample(final, x.size()[2:], mode='bilinear',align_corners=True)

# %% [markdown]
# # **4 Functions of Training, Validation**

# %% [markdown]
# ## Parameter Setting

# %%
# Network Established 
net = UNet_onelayer(num_classes = 4).cuda()


# The Hyperparameter that Optimized
batchsize=4
learningrate=1e-5



# Using decreaseing learning rate tuning
from torch.optim.lr_scheduler import ReduceLROnPlateau
min_learningrate=1e-12
lr_patience=10


# Loss function and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learningrate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
best_val_loss = 0.2

#RMSprop(net.parameters(), lr=learningrate, weight_decay=1e-8, momentum=0.9)




# Data Load
train_data_path = '/content/drive/My Drive/data/train'
train_set = TrainDataset(train_data_path)
training_data_loader = DataLoader(dataset=train_set, num_workers=4, batch_size=batchsize, shuffle=True)
valid_data_path = '/content/drive/My Drive/data/val'
valid_set = TrainDataset(valid_data_path)
valid_data_loader = DataLoader(dataset=valid_set, num_workers=4, batch_size=batchsize, shuffle=False)

model_data_path = '/content/drive/My Drive/data/model'

writer_path = os.path.join(model_data_path,'Unet_Onelayer/log')
# Record training process ( basically for ploting figure )
writer = SummaryWriter(writer_path)

# %% [markdown]
# ## AverageMeter and Validation Func

# %%
# Calculate average value of current batch
class AverageMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


####
def _fast_hist(label_pred, label_true, num_classes):
    mask = (label_true >= 0) & (label_true < num_classes)
    hist = np.bincount(
        num_classes * label_true[mask.cpu().numpy()].cpu().numpy().astype(int)+
        label_pred[mask.cpu().numpy()], 
        minlength=num_classes ** 2).reshape(num_classes, num_classes)
    return hist

###
def evaluate(predictions, gts, num_classes):
    hist = np.zeros((num_classes, num_classes))
    for lp, lt in zip(predictions, gts):
        hist += _fast_hist(lp.flatten(), lt.flatten(), num_classes)
    # axis 0: gt, axis 1: prediction
    acc = np.diag(hist).sum() / hist.sum()
    acc_cls = np.diag(hist) / hist.sum(axis=1)
    acc_cls = np.nanmean(acc_cls)
    iu = np.diag(hist) / (hist.sum(axis=1) + hist.sum(axis=0) - np.diag(hist))
    mean_iu = np.nanmean(iu)
    freq = hist.sum(axis=1) / hist.sum()
    fwavacc = (freq[freq > 0] * iu[freq > 0]).sum()
    return acc, acc_cls, mean_iu, fwavacc

# %% [markdown]
# ## Training Sec

# %%
def train(training_data_loader, net, loss_function, optimizer,epoch):
  # Change model status as Training Mode
    net.train()
    train_loss = AverageMeter()
    curr_iter = (epoch - 1) * len(training_data_loader)
    for iteration, sample in enumerate(training_data_loader):
        img, mask = sample
        img=img.unsqueeze(1).cuda() # adding 1 channel
        mask=mask.cuda()

        N = img.size(0)           # number of batch
        optimizer.zero_grad()     # CLEAR GRADIENT BUFFER
        outputs = net(img)        # FORWARD
        loss = loss_function(outputs, mask.to(dtype=torch.int64)) / N # mask type need to be long
        loss.backward()           # BACKWORD
        optimizer.step()          # UPDATE GRADIENT

        train_loss.update(loss.data.item(),N) # Average loss of this loop
        curr_iter += 1
        writer.add_scalar('train_loss', train_loss.avg, curr_iter)

        if (iteration + 1) % 10 == 0:
            print('[epoch %d], [iter %d / %d], [train loss %.5f]' % (
                  epoch+1, iteration + 1, len(training_data_loader), train_loss.avg
        ))
    return train_loss.avg

# %% [markdown]
# ## Validation sec

# %%
def validation(valid_data_loader, net, loss_function, optimizer, epoch):
    # Model Status as Evaluation Mode
    net.eval()
    val_loss = AverageMeter()
    img_all, mask_all, predictions_all = [], [], []

    for iteration, sample in enumerate(valid_data_loader): 
        img, mask = sample
        img=img.unsqueeze(1).cuda() # adding 1 channel
        mask=mask.to(dtype=torch.int64).cuda()# mask should be long type

        N = img.size(0)           # number of data
        outputs = net(img)        # FORWARD
        # Take max over 1D, return [[max of each row], [index of each max]]
        # Get the Max values index
        predictions = outputs.data.max(1)[1].squeeze_(1).squeeze_(0).cpu().numpy() 

        val_loss.update(loss_function(outputs, mask).data.item()/ N, N)
        
        with torch.no_grad():
            mask.squeeze_(0).cpu().numpy()
        mask_all.append(mask)
        predictions_all.append(predictions)
    # Accuracy, Accuracy of each columns , Mean IU, Frequency Weighted Intersection
    # Acc = Correct/Totall
    # Acc_cls = Accuracy of each class
    # IU is Recall, Mean_IU is mean Recall
    # Fwavacc is frequency times Recall
    acc, acc_cls, mean_iu, fwavacc = evaluate(predictions_all, mask_all, 4)# Number of class=4

    writer.add_scalar('val_loss', val_loss.avg, epoch)
    writer.add_scalar('acc', acc, epoch)
    writer.add_scalar('acc_cls', acc_cls, epoch)
    writer.add_scalar('mean_iu', mean_iu, epoch)
    writer.add_scalar('fwavacc', fwavacc, epoch)
    #writer.add_scalar('lr', optimizer.param_groups[1]['lr'], epoch)
    
    print('====================================================================')
    print('[epoch %d], [val loss %.5f], [acc %.5f], [acc_cls %.5f], [mean_iu %.5f], [fwavacc %.5f]' % (
        epoch+1, val_loss.avg, acc, acc_cls, mean_iu, fwavacc))
    print('====================================================================')

    return val_loss.avg

# %% [markdown]
# # **5 Training and validating**

# %%
# Epochs
epochs=150


#Training and Validation
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=lr_patience, min_lr=min_learningrate, verbose=True)# With Learning Decreasing
for epoch in range(epochs):
    PATH = os.path.join(model_data_path, 'Unet_Onelayer/Bestmodel_epoch_'+ str(epoch)+'.pth')
    train_loss = train(training_data_loader, net, loss_function, optimizer,epoch)
    val_loss = validation(valid_data_loader, net, loss_function, optimizer, epoch)
    # Draw train val map
    writer.add_scalars('train/val loss', {
                                        'train_loss':train_loss,
                                        'val_loss':val_loss}, epoch)
    # Save the best model
    if val_loss < best_val_loss:
        print(f"Model Saved at {PATH}")
        best_val_loss = val_loss
        torch.save(net.state_dict(), PATH)
    scheduler.step(val_loss)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2952: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# [epoch 1], [iter 10 / 25], [train loss 0.46802]
# [epoch 1], [iter 20 / 25], [train loss 0.45452]
# ====================================================================
# [epoch 1], [val loss 0.45146], [acc 0.13014], [acc_cls 0.29919], [mean_iu 0.06093], [fwavacc 0.07013]
# ====================================================================
# [epoch 2], [iter 10 / 25], [train loss 0.41806]
# [epoch 2], [iter 20 / 25], [train loss 0.41287]
# ====================================================================
# [epoch 2], [val loss 0.43745], [acc 0.23624], [acc_cls 0.35666], [mean_iu 0.10456], [fwavacc 0.17424]
# ====================================================================
# [epoch 3], [iter 10 / 25], [train loss 0.38427]
# [epoch 3], [iter 20 / 25], [train loss 0.38196]
# ====================================================================
# [epoch 3], [val loss 0.43140], [acc 0.32431], [acc_cls 0.39622], [mean_iu 0.14120], [fwavacc 0.26129]
# ====================================================================
# [epoch 4], [iter 10 / 25], [train loss 0.36739]
# [epoch 4], [iter 20 / 25], [train loss 0.36116]
# ====================================================================
# [epoch 4], [val loss 0.39158], [acc 0.42922], [acc_cls 0.44314], [mean_iu 0.18867], [fwavacc 0.36563]
# ====================================================================
# [epoch 5], [iter 10 / 25], [train loss 0.34026]
# [epoch 5], [iter 20 / 25], [train loss 0.33097]
# ====================================================================
# [epoch 5], [val loss 0.37201], [acc 0.50505], [acc_cls 0.48720], [mean_iu 0.22923], [fwavacc 0.43997]
# ====================================================================
# [epoch 6], [iter 10 / 25], [train loss 0.30316]
# [epoch 6], [iter 20 / 25], [train loss 0.29462]
# ====================================================================
# [epoch 6], [val loss 0.30888], [acc 0.59891], [acc_cls 0.54819], [mean_iu 0.28545], [fwavacc 0.53173]
# ====================================================================
# [epoch 7], [iter 10 / 25], [train loss 0.27467]
# [epoch 7], [iter 20 / 25], [train loss 0.26126]
# ====================================================================
# [epoch 7], [val loss 0.24539], [acc 0.71552], [acc_cls 0.59739], [mean_iu 0.35489], [fwavacc 0.64938]
# ====================================================================
# [epoch 8], [iter 10 / 25], [train loss 0.23057]
# [epoch 8], [iter 20 / 25], [train loss 0.22883]
# ====================================================================
# [epoch 8], [val loss 0.21142], [acc 0.79907], [acc_cls 0.60421], [mean_iu 0.40435], [fwavacc 0.73188]
# ====================================================================
# [epoch 9], [iter 10 / 25], [train loss 0.20753]
# [epoch 9], [iter 20 / 25], [train loss 0.20566]
# ====================================================================
# [epoch 9], [val loss 0.19204], [acc 0.84446], [acc_cls 0.61492], [mean_iu 0.44732], [fwavacc 0.77855]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_8.pth
# [epoch 10], [iter 10 / 25], [train loss 0.19385]
# [epoch 10], [iter 20 / 25], [train loss 0.18751]
# ====================================================================
# [epoch 10], [val loss 0.18719], [acc 0.85820], [acc_cls 0.68958], [mean_iu 0.49778], [fwavacc 0.79950]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_9.pth
# [epoch 11], [iter 10 / 25], [train loss 0.17447]
# [epoch 11], [iter 20 / 25], [train loss 0.17362]
# ====================================================================
# [epoch 11], [val loss 0.16624], [acc 0.89290], [acc_cls 0.63219], [mean_iu 0.51528], [fwavacc 0.83056]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_10.pth
# [epoch 12], [iter 10 / 25], [train loss 0.16120]
# [epoch 12], [iter 20 / 25], [train loss 0.15929]
# ====================================================================
# [epoch 12], [val loss 0.16014], [acc 0.89920], [acc_cls 0.68910], [mean_iu 0.55155], [fwavacc 0.84320]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_11.pth
# [epoch 13], [iter 10 / 25], [train loss 0.15062]
# [epoch 13], [iter 20 / 25], [train loss 0.14970]
# ====================================================================
# [epoch 13], [val loss 0.15047], [acc 0.90952], [acc_cls 0.69091], [mean_iu 0.57036], [fwavacc 0.85458]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_12.pth
# [epoch 14], [iter 10 / 25], [train loss 0.14330]
# [epoch 14], [iter 20 / 25], [train loss 0.14212]
# ====================================================================
# [epoch 14], [val loss 0.14618], [acc 0.91384], [acc_cls 0.73131], [mean_iu 0.59840], [fwavacc 0.86244]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_13.pth
# [epoch 15], [iter 10 / 25], [train loss 0.13445]
# [epoch 15], [iter 20 / 25], [train loss 0.13560]
# ====================================================================
# [epoch 15], [val loss 0.13934], [acc 0.90849], [acc_cls 0.60364], [mean_iu 0.53137], [fwavacc 0.84465]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_14.pth
# [epoch 16], [iter 10 / 25], [train loss 0.13120]
# [epoch 16], [iter 20 / 25], [train loss 0.13139]
# ====================================================================
# [epoch 16], [val loss 0.13374], [acc 0.92397], [acc_cls 0.73327], [mean_iu 0.62017], [fwavacc 0.87467]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_15.pth
# [epoch 17], [iter 10 / 25], [train loss 0.12311]
# [epoch 17], [iter 20 / 25], [train loss 0.12187]
# ====================================================================
# [epoch 17], [val loss 0.13354], [acc 0.91762], [acc_cls 0.77809], [mean_iu 0.63061], [fwavacc 0.86957]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_16.pth
# [epoch 18], [iter 10 / 25], [train loss 0.11843]
# [epoch 18], [iter 20 / 25], [train loss 0.11854]
# ====================================================================
# [epoch 18], [val loss 0.12253], [acc 0.93051], [acc_cls 0.73152], [mean_iu 0.63442], [fwavacc 0.88302]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_17.pth
# [epoch 19], [iter 10 / 25], [train loss 0.11309]
# [epoch 19], [iter 20 / 25], [train loss 0.11322]
# ====================================================================
# [epoch 19], [val loss 0.12178], [acc 0.92935], [acc_cls 0.77834], [mean_iu 0.65627], [fwavacc 0.88380]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_18.pth
# [epoch 20], [iter 10 / 25], [train loss 0.11181]
# [epoch 20], [iter 20 / 25], [train loss 0.10903]
# ====================================================================
# [epoch 20], [val loss 0.13203], [acc 0.91335], [acc_cls 0.82874], [mean_iu 0.64841], [fwavacc 0.86539]
# ====================================================================
# [epoch 21], [iter 10 / 25], [train loss 0.10861]
# [epoch 21], [iter 20 / 25], [train loss 0.10573]
# ====================================================================
# [epoch 21], [val loss 0.11539], [acc 0.93178], [acc_cls 0.79078], [mean_iu 0.66995], [fwavacc 0.88756]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_20.pth
# [epoch 22], [iter 10 / 25], [train loss 0.10374]
# [epoch 22], [iter 20 / 25], [train loss 0.10256]
# ====================================================================
# [epoch 22], [val loss 0.12395], [acc 0.92080], [acc_cls 0.84028], [mean_iu 0.67010], [fwavacc 0.87536]
# ====================================================================
# [epoch 23], [iter 10 / 25], [train loss 0.10089]
# [epoch 23], [iter 20 / 25], [train loss 0.09960]
# ====================================================================
# [epoch 23], [val loss 0.10878], [acc 0.93405], [acc_cls 0.79318], [mean_iu 0.67902], [fwavacc 0.89025]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_22.pth
# [epoch 24], [iter 10 / 25], [train loss 0.09784]
# [epoch 24], [iter 20 / 25], [train loss 0.09655]
# ====================================================================
# [epoch 24], [val loss 0.10496], [acc 0.93853], [acc_cls 0.75881], [mean_iu 0.67190], [fwavacc 0.89390]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_23.pth
# [epoch 25], [iter 10 / 25], [train loss 0.09528]
# [epoch 25], [iter 20 / 25], [train loss 0.09373]
# ====================================================================
# [epoch 25], [val loss 0.10292], [acc 0.94052], [acc_cls 0.80611], [mean_iu 0.69984], [fwavacc 0.89875]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_24.pth
# [epoch 26], [iter 10 / 25], [train loss 0.09227]
# [epoch 26], [iter 20 / 25], [train loss 0.09120]
# ====================================================================
# [epoch 26], [val loss 0.10549], [acc 0.93626], [acc_cls 0.84614], [mean_iu 0.70586], [fwavacc 0.89479]
# ====================================================================
# [epoch 27], [iter 10 / 25], [train loss 0.08541]
# [epoch 27], [iter 20 / 25], [train loss 0.08775]
# ====================================================================
# [epoch 27], [val loss 0.10252], [acc 0.93641], [acc_cls 0.83338], [mean_iu 0.70388], [fwavacc 0.89501]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_26.pth
# [epoch 28], [iter 10 / 25], [train loss 0.08890]
# [epoch 28], [iter 20 / 25], [train loss 0.08703]
# ====================================================================
# [epoch 28], [val loss 0.10688], [acc 0.92961], [acc_cls 0.84601], [mean_iu 0.69510], [fwavacc 0.88604]
# ====================================================================
# [epoch 29], [iter 10 / 25], [train loss 0.08374]
# [epoch 29], [iter 20 / 25], [train loss 0.08328]
# ====================================================================
# [epoch 29], [val loss 0.10230], [acc 0.93472], [acc_cls 0.84465], [mean_iu 0.70422], [fwavacc 0.89257]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_28.pth
# [epoch 30], [iter 10 / 25], [train loss 0.08521]
# [epoch 30], [iter 20 / 25], [train loss 0.08411]
# ====================================================================
# [epoch 30], [val loss 0.09347], [acc 0.94419], [acc_cls 0.82277], [mean_iu 0.71956], [fwavacc 0.90439]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_29.pth
# [epoch 31], [iter 10 / 25], [train loss 0.08098]
# [epoch 31], [iter 20 / 25], [train loss 0.08035]
# ====================================================================
# [epoch 31], [val loss 0.09678], [acc 0.94123], [acc_cls 0.85348], [mean_iu 0.72451], [fwavacc 0.90145]
# ====================================================================
# [epoch 32], [iter 10 / 25], [train loss 0.07833]
# [epoch 32], [iter 20 / 25], [train loss 0.07853]
# ====================================================================
# [epoch 32], [val loss 0.09265], [acc 0.94561], [acc_cls 0.83288], [mean_iu 0.72746], [fwavacc 0.90627]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_31.pth
# [epoch 33], [iter 10 / 25], [train loss 0.07958]
# [epoch 33], [iter 20 / 25], [train loss 0.07845]
# ====================================================================
# [epoch 33], [val loss 0.09094], [acc 0.94476], [acc_cls 0.83628], [mean_iu 0.72736], [fwavacc 0.90596]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_32.pth
# [epoch 34], [iter 10 / 25], [train loss 0.07726]
# [epoch 34], [iter 20 / 25], [train loss 0.07681]
# ====================================================================
# [epoch 34], [val loss 0.08998], [acc 0.94361], [acc_cls 0.81569], [mean_iu 0.71633], [fwavacc 0.90222]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_33.pth
# [epoch 35], [iter 10 / 25], [train loss 0.07340]
# [epoch 35], [iter 20 / 25], [train loss 0.07510]
# ====================================================================
# [epoch 35], [val loss 0.09247], [acc 0.94050], [acc_cls 0.83906], [mean_iu 0.71938], [fwavacc 0.90013]
# ====================================================================
# [epoch 36], [iter 10 / 25], [train loss 0.07514]
# [epoch 36], [iter 20 / 25], [train loss 0.07470]
# ====================================================================
# [epoch 36], [val loss 0.09093], [acc 0.94237], [acc_cls 0.85254], [mean_iu 0.73053], [fwavacc 0.90338]
# ====================================================================
# [epoch 37], [iter 10 / 25], [train loss 0.07440]
# [epoch 37], [iter 20 / 25], [train loss 0.07356]
# ====================================================================
# [epoch 37], [val loss 0.09070], [acc 0.94250], [acc_cls 0.86066], [mean_iu 0.73177], [fwavacc 0.90321]
# ====================================================================
# [epoch 38], [iter 10 / 25], [train loss 0.07071]
# [epoch 38], [iter 20 / 25], [train loss 0.07347]
# ====================================================================
# [epoch 38], [val loss 0.08735], [acc 0.94398], [acc_cls 0.84943], [mean_iu 0.73283], [fwavacc 0.90542]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_37.pth
# [epoch 39], [iter 10 / 25], [train loss 0.07346]
# [epoch 39], [iter 20 / 25], [train loss 0.07262]
# ====================================================================
# [epoch 39], [val loss 0.08525], [acc 0.94849], [acc_cls 0.84759], [mean_iu 0.74307], [fwavacc 0.91111]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_38.pth
# [epoch 40], [iter 10 / 25], [train loss 0.06863]
# [epoch 40], [iter 20 / 25], [train loss 0.06965]
# ====================================================================
# [epoch 40], [val loss 0.08693], [acc 0.94090], [acc_cls 0.83210], [mean_iu 0.71632], [fwavacc 0.90158]
# ====================================================================
# [epoch 41], [iter 10 / 25], [train loss 0.06936]
# [epoch 41], [iter 20 / 25], [train loss 0.06858]
# ====================================================================
# [epoch 41], [val loss 0.08614], [acc 0.94363], [acc_cls 0.85073], [mean_iu 0.73342], [fwavacc 0.90527]
# ====================================================================
# [epoch 42], [iter 10 / 25], [train loss 0.06909]
# [epoch 42], [iter 20 / 25], [train loss 0.06853]
# ====================================================================
# [epoch 42], [val loss 0.08237], [acc 0.95035], [acc_cls 0.85356], [mean_iu 0.75048], [fwavacc 0.91413]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_41.pth
# [epoch 43], [iter 10 / 25], [train loss 0.06545]
# [epoch 43], [iter 20 / 25], [train loss 0.06712]
# ====================================================================
# [epoch 43], [val loss 0.08584], [acc 0.94348], [acc_cls 0.85732], [mean_iu 0.73653], [fwavacc 0.90490]
# ====================================================================
# [epoch 44], [iter 10 / 25], [train loss 0.06635]
# [epoch 44], [iter 20 / 25], [train loss 0.06684]
# ====================================================================
# [epoch 44], [val loss 0.08393], [acc 0.94447], [acc_cls 0.85224], [mean_iu 0.73515], [fwavacc 0.90678]
# ====================================================================
# [epoch 45], [iter 10 / 25], [train loss 0.06488]
# [epoch 45], [iter 20 / 25], [train loss 0.06469]
# ====================================================================
# [epoch 45], [val loss 0.08012], [acc 0.94903], [acc_cls 0.84576], [mean_iu 0.74409], [fwavacc 0.91200]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_44.pth
# [epoch 46], [iter 10 / 25], [train loss 0.06380]
# [epoch 46], [iter 20 / 25], [train loss 0.06473]
# ====================================================================
# [epoch 46], [val loss 0.07886], [acc 0.94889], [acc_cls 0.83886], [mean_iu 0.73939], [fwavacc 0.91158]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_45.pth
# [epoch 47], [iter 10 / 25], [train loss 0.06408]
# [epoch 47], [iter 20 / 25], [train loss 0.06456]
# ====================================================================
# [epoch 47], [val loss 0.07888], [acc 0.94616], [acc_cls 0.82683], [mean_iu 0.72481], [fwavacc 0.90803]
# ====================================================================
# [epoch 48], [iter 10 / 25], [train loss 0.06166]
# [epoch 48], [iter 20 / 25], [train loss 0.06324]
# ====================================================================
# [epoch 48], [val loss 0.07741], [acc 0.95099], [acc_cls 0.84771], [mean_iu 0.75091], [fwavacc 0.91424]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_47.pth
# [epoch 49], [iter 10 / 25], [train loss 0.06276]
# [epoch 49], [iter 20 / 25], [train loss 0.06233]
# ====================================================================
# [epoch 49], [val loss 0.08086], [acc 0.94664], [acc_cls 0.87444], [mean_iu 0.74909], [fwavacc 0.91013]
# ====================================================================
# [epoch 50], [iter 10 / 25], [train loss 0.06243]
# [epoch 50], [iter 20 / 25], [train loss 0.06190]
# ====================================================================
# [epoch 50], [val loss 0.07644], [acc 0.94581], [acc_cls 0.80799], [mean_iu 0.71702], [fwavacc 0.90598]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_49.pth
# [epoch 51], [iter 10 / 25], [train loss 0.06169]
# [epoch 51], [iter 20 / 25], [train loss 0.06213]
# ====================================================================
# [epoch 51], [val loss 0.08015], [acc 0.94431], [acc_cls 0.86663], [mean_iu 0.74199], [fwavacc 0.90670]
# ====================================================================
# [epoch 52], [iter 10 / 25], [train loss 0.06221]
# [epoch 52], [iter 20 / 25], [train loss 0.06235]
# ====================================================================
# [epoch 52], [val loss 0.08497], [acc 0.93873], [acc_cls 0.87266], [mean_iu 0.73250], [fwavacc 0.89955]
# ====================================================================
# [epoch 53], [iter 10 / 25], [train loss 0.05973]
# [epoch 53], [iter 20 / 25], [train loss 0.05918]
# ====================================================================
# [epoch 53], [val loss 0.07765], [acc 0.94587], [acc_cls 0.84676], [mean_iu 0.73829], [fwavacc 0.90733]
# ====================================================================
# [epoch 54], [iter 10 / 25], [train loss 0.05949]
# [epoch 54], [iter 20 / 25], [train loss 0.05830]
# ====================================================================
# [epoch 54], [val loss 0.07774], [acc 0.94640], [acc_cls 0.86526], [mean_iu 0.74668], [fwavacc 0.90946]
# ====================================================================
# [epoch 55], [iter 10 / 25], [train loss 0.05576]
# [epoch 55], [iter 20 / 25], [train loss 0.05929]
# ====================================================================
# [epoch 55], [val loss 0.07569], [acc 0.94694], [acc_cls 0.84065], [mean_iu 0.73636], [fwavacc 0.90892]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_54.pth
# [epoch 56], [iter 10 / 25], [train loss 0.05980]
# [epoch 56], [iter 20 / 25], [train loss 0.05799]
# ====================================================================
# [epoch 56], [val loss 0.07437], [acc 0.94939], [acc_cls 0.86885], [mean_iu 0.75296], [fwavacc 0.91418]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_55.pth
# [epoch 57], [iter 10 / 25], [train loss 0.05731]
# [epoch 57], [iter 20 / 25], [train loss 0.05740]
# ====================================================================
# [epoch 57], [val loss 0.07940], [acc 0.94011], [acc_cls 0.85514], [mean_iu 0.72687], [fwavacc 0.90101]
# ====================================================================
# [epoch 58], [iter 10 / 25], [train loss 0.05784]
# [epoch 58], [iter 20 / 25], [train loss 0.05726]
# ====================================================================
# [epoch 58], [val loss 0.07100], [acc 0.95355], [acc_cls 0.85777], [mean_iu 0.76099], [fwavacc 0.91864]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_57.pth
# [epoch 59], [iter 10 / 25], [train loss 0.05536]
# [epoch 59], [iter 20 / 25], [train loss 0.05543]
# ====================================================================
# [epoch 59], [val loss 0.07543], [acc 0.94627], [acc_cls 0.86310], [mean_iu 0.74450], [fwavacc 0.90928]
# ====================================================================
# [epoch 60], [iter 10 / 25], [train loss 0.05603]
# [epoch 60], [iter 20 / 25], [train loss 0.05582]
# ====================================================================
# [epoch 60], [val loss 0.07248], [acc 0.95146], [acc_cls 0.86819], [mean_iu 0.75973], [fwavacc 0.91618]
# ====================================================================
# [epoch 61], [iter 10 / 25], [train loss 0.05431]
# [epoch 61], [iter 20 / 25], [train loss 0.05474]
# ====================================================================
# [epoch 61], [val loss 0.07080], [acc 0.94943], [acc_cls 0.84737], [mean_iu 0.74524], [fwavacc 0.91283]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_60.pth
# [epoch 62], [iter 10 / 25], [train loss 0.05424]
# [epoch 62], [iter 20 / 25], [train loss 0.05514]
# ====================================================================
# [epoch 62], [val loss 0.07326], [acc 0.94606], [acc_cls 0.85221], [mean_iu 0.73915], [fwavacc 0.90857]
# ====================================================================
# [epoch 63], [iter 10 / 25], [train loss 0.05337]
# [epoch 63], [iter 20 / 25], [train loss 0.05358]
# ====================================================================
# [epoch 63], [val loss 0.07679], [acc 0.94121], [acc_cls 0.86458], [mean_iu 0.73502], [fwavacc 0.90261]
# ====================================================================
# [epoch 64], [iter 10 / 25], [train loss 0.05340]
# [epoch 64], [iter 20 / 25], [train loss 0.05314]
# ====================================================================
# [epoch 64], [val loss 0.07205], [acc 0.94910], [acc_cls 0.86991], [mean_iu 0.75502], [fwavacc 0.91325]
# ====================================================================
# [epoch 65], [iter 10 / 25], [train loss 0.05489]
# [epoch 65], [iter 20 / 25], [train loss 0.05336]
# ====================================================================
# [epoch 65], [val loss 0.07167], [acc 0.94997], [acc_cls 0.88206], [mean_iu 0.76073], [fwavacc 0.91552]
# ====================================================================
# [epoch 66], [iter 10 / 25], [train loss 0.05211]
# [epoch 66], [iter 20 / 25], [train loss 0.05284]
# ====================================================================
# [epoch 66], [val loss 0.06733], [acc 0.95353], [acc_cls 0.83579], [mean_iu 0.75449], [fwavacc 0.91720]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_65.pth
# [epoch 67], [iter 10 / 25], [train loss 0.05301]
# [epoch 67], [iter 20 / 25], [train loss 0.05213]
# ====================================================================
# [epoch 67], [val loss 0.06910], [acc 0.94907], [acc_cls 0.85573], [mean_iu 0.74827], [fwavacc 0.91285]
# ====================================================================
# [epoch 68], [iter 10 / 25], [train loss 0.05130]
# [epoch 68], [iter 20 / 25], [train loss 0.05121]
# ====================================================================
# [epoch 68], [val loss 0.07193], [acc 0.94709], [acc_cls 0.87328], [mean_iu 0.75235], [fwavacc 0.91063]
# ====================================================================
# [epoch 69], [iter 10 / 25], [train loss 0.05121]
# [epoch 69], [iter 20 / 25], [train loss 0.05171]
# ====================================================================
# [epoch 69], [val loss 0.07598], [acc 0.94310], [acc_cls 0.88163], [mean_iu 0.74582], [fwavacc 0.90506]
# ====================================================================
# [epoch 70], [iter 10 / 25], [train loss 0.05194]
# [epoch 70], [iter 20 / 25], [train loss 0.05155]
# ====================================================================
# [epoch 70], [val loss 0.07607], [acc 0.94300], [acc_cls 0.87806], [mean_iu 0.74378], [fwavacc 0.90450]
# ====================================================================
# [epoch 71], [iter 10 / 25], [train loss 0.04956]
# [epoch 71], [iter 20 / 25], [train loss 0.05030]
# ====================================================================
# [epoch 71], [val loss 0.07559], [acc 0.94027], [acc_cls 0.87345], [mean_iu 0.73644], [fwavacc 0.90237]
# ====================================================================
# [epoch 72], [iter 10 / 25], [train loss 0.05136]
# [epoch 72], [iter 20 / 25], [train loss 0.05048]
# ====================================================================
# [epoch 72], [val loss 0.07440], [acc 0.94229], [acc_cls 0.87952], [mean_iu 0.74335], [fwavacc 0.90397]
# ====================================================================
# [epoch 73], [iter 10 / 25], [train loss 0.05165]
# [epoch 73], [iter 20 / 25], [train loss 0.05012]
# ====================================================================
# [epoch 73], [val loss 0.06622], [acc 0.94984], [acc_cls 0.85689], [mean_iu 0.75099], [fwavacc 0.91383]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_72.pth
# [epoch 74], [iter 10 / 25], [train loss 0.04931]
# [epoch 74], [iter 20 / 25], [train loss 0.04896]
# ====================================================================
# [epoch 74], [val loss 0.06560], [acc 0.95284], [acc_cls 0.86296], [mean_iu 0.76252], [fwavacc 0.91769]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_73.pth
# [epoch 75], [iter 10 / 25], [train loss 0.04876]
# [epoch 75], [iter 20 / 25], [train loss 0.04778]
# ====================================================================
# [epoch 75], [val loss 0.06771], [acc 0.94697], [acc_cls 0.85124], [mean_iu 0.74003], [fwavacc 0.90985]
# ====================================================================
# [epoch 76], [iter 10 / 25], [train loss 0.04825]
# [epoch 76], [iter 20 / 25], [train loss 0.04784]
# ====================================================================
# [epoch 76], [val loss 0.06758], [acc 0.94689], [acc_cls 0.84993], [mean_iu 0.73986], [fwavacc 0.90950]
# ====================================================================
# [epoch 77], [iter 10 / 25], [train loss 0.04876]
# [epoch 77], [iter 20 / 25], [train loss 0.04814]
# ====================================================================
# [epoch 77], [val loss 0.06410], [acc 0.95420], [acc_cls 0.87859], [mean_iu 0.77197], [fwavacc 0.92041]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_76.pth
# [epoch 78], [iter 10 / 25], [train loss 0.04721]
# [epoch 78], [iter 20 / 25], [train loss 0.04825]
# ====================================================================
# [epoch 78], [val loss 0.07008], [acc 0.94352], [acc_cls 0.85944], [mean_iu 0.73910], [fwavacc 0.90504]
# ====================================================================
# [epoch 79], [iter 10 / 25], [train loss 0.04754]
# [epoch 79], [iter 20 / 25], [train loss 0.04727]
# ====================================================================
# [epoch 79], [val loss 0.06663], [acc 0.94852], [acc_cls 0.86890], [mean_iu 0.75320], [fwavacc 0.91256]
# ====================================================================
# [epoch 80], [iter 10 / 25], [train loss 0.04617]
# [epoch 80], [iter 20 / 25], [train loss 0.04716]
# ====================================================================
# [epoch 80], [val loss 0.06823], [acc 0.94583], [acc_cls 0.87129], [mean_iu 0.74942], [fwavacc 0.90871]
# ====================================================================
# [epoch 81], [iter 10 / 25], [train loss 0.04467]
# [epoch 81], [iter 20 / 25], [train loss 0.04648]
# ====================================================================
# [epoch 81], [val loss 0.06996], [acc 0.94502], [acc_cls 0.88024], [mean_iu 0.75174], [fwavacc 0.90794]
# ====================================================================
# [epoch 82], [iter 10 / 25], [train loss 0.04481]
# [epoch 82], [iter 20 / 25], [train loss 0.04553]
# ====================================================================
# [epoch 82], [val loss 0.06570], [acc 0.95094], [acc_cls 0.88418], [mean_iu 0.76565], [fwavacc 0.91624]
# ====================================================================
# [epoch 83], [iter 10 / 25], [train loss 0.04461]
# [epoch 83], [iter 20 / 25], [train loss 0.04480]
# ====================================================================
# [epoch 83], [val loss 0.06926], [acc 0.94683], [acc_cls 0.88912], [mean_iu 0.75927], [fwavacc 0.91060]
# ====================================================================
# [epoch 84], [iter 10 / 25], [train loss 0.04356]
# [epoch 84], [iter 20 / 25], [train loss 0.04385]
# ====================================================================
# [epoch 84], [val loss 0.06277], [acc 0.95221], [acc_cls 0.86175], [mean_iu 0.75989], [fwavacc 0.91692]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_83.pth
# [epoch 85], [iter 10 / 25], [train loss 0.04432]
# [epoch 85], [iter 20 / 25], [train loss 0.04463]
# ====================================================================
# [epoch 85], [val loss 0.06514], [acc 0.94898], [acc_cls 0.88122], [mean_iu 0.76092], [fwavacc 0.91392]
# ====================================================================
# [epoch 86], [iter 10 / 25], [train loss 0.04405]
# [epoch 86], [iter 20 / 25], [train loss 0.04383]
# ====================================================================
# [epoch 86], [val loss 0.06522], [acc 0.94747], [acc_cls 0.86828], [mean_iu 0.74994], [fwavacc 0.91107]
# ====================================================================
# [epoch 87], [iter 10 / 25], [train loss 0.04406]
# [epoch 87], [iter 20 / 25], [train loss 0.04356]
# ====================================================================
# [epoch 87], [val loss 0.06701], [acc 0.94648], [acc_cls 0.87956], [mean_iu 0.75531], [fwavacc 0.90968]
# ====================================================================
# [epoch 88], [iter 10 / 25], [train loss 0.04319]
# [epoch 88], [iter 20 / 25], [train loss 0.04313]
# ====================================================================
# [epoch 88], [val loss 0.06673], [acc 0.94504], [acc_cls 0.87009], [mean_iu 0.74615], [fwavacc 0.90808]
# ====================================================================
# [epoch 89], [iter 10 / 25], [train loss 0.04364]
# [epoch 89], [iter 20 / 25], [train loss 0.04322]
# ====================================================================
# [epoch 89], [val loss 0.06955], [acc 0.94411], [acc_cls 0.88877], [mean_iu 0.75412], [fwavacc 0.90718]
# ====================================================================
# [epoch 90], [iter 10 / 25], [train loss 0.04265]
# [epoch 90], [iter 20 / 25], [train loss 0.04239]
# ====================================================================
# [epoch 90], [val loss 0.07514], [acc 0.93759], [acc_cls 0.89085], [mean_iu 0.74073], [fwavacc 0.89877]
# ====================================================================
# [epoch 91], [iter 10 / 25], [train loss 0.04306]
# [epoch 91], [iter 20 / 25], [train loss 0.04260]
# ====================================================================
# [epoch 91], [val loss 0.06455], [acc 0.94730], [acc_cls 0.87408], [mean_iu 0.75377], [fwavacc 0.91086]
# ====================================================================
# [epoch 92], [iter 10 / 25], [train loss 0.04174]
# [epoch 92], [iter 20 / 25], [train loss 0.04219]
# ====================================================================
# [epoch 92], [val loss 0.06557], [acc 0.94532], [acc_cls 0.86707], [mean_iu 0.74513], [fwavacc 0.90797]
# ====================================================================
# [epoch 93], [iter 10 / 25], [train loss 0.04149]
# [epoch 93], [iter 20 / 25], [train loss 0.04215]
# ====================================================================
# [epoch 93], [val loss 0.06275], [acc 0.94882], [acc_cls 0.87769], [mean_iu 0.75881], [fwavacc 0.91310]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_92.pth
# [epoch 94], [iter 10 / 25], [train loss 0.04090]
# [epoch 94], [iter 20 / 25], [train loss 0.04158]
# ====================================================================
# [epoch 94], [val loss 0.06448], [acc 0.94787], [acc_cls 0.87799], [mean_iu 0.75614], [fwavacc 0.91181]
# ====================================================================
# [epoch 95], [iter 10 / 25], [train loss 0.04021]
# [epoch 95], [iter 20 / 25], [train loss 0.04063]
# ====================================================================
# [epoch 95], [val loss 0.07019], [acc 0.94270], [acc_cls 0.89262], [mean_iu 0.75185], [fwavacc 0.90568]
# ====================================================================
# [epoch 96], [iter 10 / 25], [train loss 0.04150]
# [epoch 96], [iter 20 / 25], [train loss 0.04134]
# ====================================================================
# [epoch 96], [val loss 0.06870], [acc 0.94249], [acc_cls 0.88415], [mean_iu 0.74558], [fwavacc 0.90533]
# ====================================================================
# [epoch 97], [iter 10 / 25], [train loss 0.04059]
# [epoch 97], [iter 20 / 25], [train loss 0.04051]
# ====================================================================
# [epoch 97], [val loss 0.06218], [acc 0.94857], [acc_cls 0.87670], [mean_iu 0.75831], [fwavacc 0.91276]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_96.pth
# [epoch 98], [iter 10 / 25], [train loss 0.03896]
# [epoch 98], [iter 20 / 25], [train loss 0.03973]
# ====================================================================
# [epoch 98], [val loss 0.06731], [acc 0.94388], [acc_cls 0.88787], [mean_iu 0.75193], [fwavacc 0.90681]
# ====================================================================
# [epoch 99], [iter 10 / 25], [train loss 0.03969]
# [epoch 99], [iter 20 / 25], [train loss 0.03962]
# ====================================================================
# [epoch 99], [val loss 0.06524], [acc 0.94404], [acc_cls 0.86711], [mean_iu 0.74176], [fwavacc 0.90648]
# ====================================================================
# [epoch 100], [iter 10 / 25], [train loss 0.04116]
# [epoch 100], [iter 20 / 25], [train loss 0.04001]
# ====================================================================
# [epoch 100], [val loss 0.05570], [acc 0.95583], [acc_cls 0.86243], [mean_iu 0.77264], [fwavacc 0.92168]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_99.pth
# [epoch 101], [iter 10 / 25], [train loss 0.03974]
# [epoch 101], [iter 20 / 25], [train loss 0.03877]
# ====================================================================
# [epoch 101], [val loss 0.06220], [acc 0.94556], [acc_cls 0.85337], [mean_iu 0.73789], [fwavacc 0.90782]
# ====================================================================
# [epoch 102], [iter 10 / 25], [train loss 0.03917]
# [epoch 102], [iter 20 / 25], [train loss 0.03906]
# ====================================================================
# [epoch 102], [val loss 0.05552], [acc 0.95457], [acc_cls 0.84553], [mean_iu 0.76013], [fwavacc 0.91930]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet_Onelayer/Bestmodel_epoch_101.pth
# [epoch 103], [iter 10 / 25], [train loss 0.03728]
# [epoch 103], [iter 20 / 25], [train loss 0.03753]
# ====================================================================
# [epoch 103], [val loss 0.06045], [acc 0.94863], [acc_cls 0.86451], [mean_iu 0.75286], [fwavacc 0.91198]
# ====================================================================
# [epoch 104], [iter 10 / 25], [train loss 0.03906]
# [epoch 104], [iter 20 / 25], [train loss 0.03789]
# ====================================================================
# [epoch 104], [val loss 0.07186], [acc 0.93695], [acc_cls 0.89151], [mean_iu 0.74050], [fwavacc 0.89858]
# ====================================================================
# [epoch 105], [iter 10 / 25], [train loss 0.03729]
# [epoch 105], [iter 20 / 25], [train loss 0.03778]
# ====================================================================
# [epoch 105], [val loss 0.06412], [acc 0.94434], [acc_cls 0.87879], [mean_iu 0.74910], [fwavacc 0.90713]
# ====================================================================
# [epoch 106], [iter 10 / 25], [train loss 0.03655]
# [epoch 106], [iter 20 / 25], [train loss 0.03818]
# ====================================================================
# [epoch 106], [val loss 0.06296], [acc 0.94507], [acc_cls 0.87235], [mean_iu 0.74945], [fwavacc 0.90803]
# ====================================================================
# [epoch 107], [iter 10 / 25], [train loss 0.03813]
# [epoch 107], [iter 20 / 25], [train loss 0.03721]
# ====================================================================
# [epoch 107], [val loss 0.05778], [acc 0.95161], [acc_cls 0.87423], [mean_iu 0.76106], [fwavacc 0.91728]
# ====================================================================
# [epoch 108], [iter 10 / 25], [train loss 0.03894]
# [epoch 108], [iter 20 / 25], [train loss 0.03725]
# ====================================================================
# [epoch 108], [val loss 0.05803], [acc 0.95085], [acc_cls 0.88141], [mean_iu 0.76627], [fwavacc 0.91593]
# ====================================================================
# [epoch 109], [iter 10 / 25], [train loss 0.03790]
# [epoch 109], [iter 20 / 25], [train loss 0.03719]
# ====================================================================
# [epoch 109], [val loss 0.06870], [acc 0.93688], [acc_cls 0.87595], [mean_iu 0.73088], [fwavacc 0.89764]
# ====================================================================
# [epoch 110], [iter 10 / 25], [train loss 0.03569]
# [epoch 110], [iter 20 / 25], [train loss 0.03586]
# ====================================================================
# [epoch 110], [val loss 0.05738], [acc 0.95111], [acc_cls 0.86541], [mean_iu 0.75969], [fwavacc 0.91532]
# ====================================================================
# [epoch 111], [iter 10 / 25], [train loss 0.03742]
# [epoch 111], [iter 20 / 25], [train loss 0.03663]
# ====================================================================
# [epoch 111], [val loss 0.06206], [acc 0.94521], [acc_cls 0.88288], [mean_iu 0.75259], [fwavacc 0.90877]
# ====================================================================
# [epoch 112], [iter 10 / 25], [train loss 0.03656]
# [epoch 112], [iter 20 / 25], [train loss 0.03619]
# ====================================================================
# [epoch 112], [val loss 0.06654], [acc 0.94172], [acc_cls 0.88881], [mean_iu 0.74858], [fwavacc 0.90451]
# ====================================================================
# [epoch 113], [iter 10 / 25], [train loss 0.03622]
# [epoch 113], [iter 20 / 25], [train loss 0.03561]
# ====================================================================
# [epoch 113], [val loss 0.07247], [acc 0.93542], [acc_cls 0.89094], [mean_iu 0.73858], [fwavacc 0.89615]
# ====================================================================
# Epoch   113: reducing learning rate of group 0 to 1.0000e-06.
# [epoch 114], [iter 10 / 25], [train loss 0.03504]
# [epoch 114], [iter 20 / 25], [train loss 0.03556]
# ====================================================================
# [epoch 114], [val loss 0.06096], [acc 0.94526], [acc_cls 0.87639], [mean_iu 0.75165], [fwavacc 0.90835]
# ====================================================================
# [epoch 115], [iter 10 / 25], [train loss 0.03615]
# [epoch 115], [iter 20 / 25], [train loss 0.03618]
# ====================================================================
# [epoch 115], [val loss 0.05950], [acc 0.94757], [acc_cls 0.87796], [mean_iu 0.75749], [fwavacc 0.91127]
# ====================================================================
# [epoch 116], [iter 10 / 25], [train loss 0.03446]
# [epoch 116], [iter 20 / 25], [train loss 0.03553]
# ====================================================================
# [epoch 116], [val loss 0.06173], [acc 0.94587], [acc_cls 0.88577], [mean_iu 0.75633], [fwavacc 0.90952]
# ====================================================================
# [epoch 117], [iter 10 / 25], [train loss 0.03518]
# [epoch 117], [iter 20 / 25], [train loss 0.03545]
# ====================================================================
# [epoch 117], [val loss 0.05923], [acc 0.94737], [acc_cls 0.87756], [mean_iu 0.75617], [fwavacc 0.91118]
# ====================================================================
# [epoch 118], [iter 10 / 25], [train loss 0.03556]
# [epoch 118], [iter 20 / 25], [train loss 0.03509]
# ====================================================================
# [epoch 118], [val loss 0.06165], [acc 0.94513], [acc_cls 0.88054], [mean_iu 0.75254], [fwavacc 0.90835]
# ====================================================================
# [epoch 119], [iter 10 / 25], [train loss 0.03477]
# [epoch 119], [iter 20 / 25], [train loss 0.03479]
# ====================================================================
# [epoch 119], [val loss 0.05972], [acc 0.94689], [acc_cls 0.87637], [mean_iu 0.75450], [fwavacc 0.91050]
# ====================================================================
# [epoch 120], [iter 10 / 25], [train loss 0.03607]
# [epoch 120], [iter 20 / 25], [train loss 0.03571]
# ====================================================================
# [epoch 120], [val loss 0.05937], [acc 0.94822], [acc_cls 0.87933], [mean_iu 0.75899], [fwavacc 0.91221]
# ====================================================================
# [epoch 121], [iter 10 / 25], [train loss 0.03557]
# [epoch 121], [iter 20 / 25], [train loss 0.03483]
# ====================================================================
# [epoch 121], [val loss 0.05921], [acc 0.94742], [acc_cls 0.87585], [mean_iu 0.75677], [fwavacc 0.91101]
# ====================================================================
# [epoch 122], [iter 10 / 25], [train loss 0.03423]
# [epoch 122], [iter 20 / 25], [train loss 0.03463]
# ====================================================================
# [epoch 122], [val loss 0.06126], [acc 0.94602], [acc_cls 0.88182], [mean_iu 0.75496], [fwavacc 0.90965]
# ====================================================================
# [epoch 123], [iter 10 / 25], [train loss 0.03463]
# [epoch 123], [iter 20 / 25], [train loss 0.03460]
# ====================================================================
# [epoch 123], [val loss 0.06109], [acc 0.94535], [acc_cls 0.87772], [mean_iu 0.75159], [fwavacc 0.90862]
# ====================================================================
# [epoch 124], [iter 10 / 25], [train loss 0.03475]
# [epoch 124], [iter 20 / 25], [train loss 0.03454]
# ====================================================================
# [epoch 124], [val loss 0.06058], [acc 0.94678], [acc_cls 0.88391], [mean_iu 0.75785], [fwavacc 0.91065]
# ====================================================================
# Epoch   124: reducing learning rate of group 0 to 1.0000e-07.
# [epoch 125], [iter 10 / 25], [train loss 0.03546]
# [epoch 125], [iter 20 / 25], [train loss 0.03476]
# ====================================================================
# [epoch 125], [val loss 0.06015], [acc 0.94593], [acc_cls 0.87392], [mean_iu 0.75008], [fwavacc 0.90924]
# ====================================================================
# [epoch 126], [iter 10 / 25], [train loss 0.03498]
# [epoch 126], [iter 20 / 25], [train loss 0.03512]
# ====================================================================
# [epoch 126], [val loss 0.05943], [acc 0.94734], [acc_cls 0.87711], [mean_iu 0.75679], [fwavacc 0.91101]
# ====================================================================
# [epoch 127], [iter 10 / 25], [train loss 0.03453]
# [epoch 127], [iter 20 / 25], [train loss 0.03520]
# ====================================================================
# [epoch 127], [val loss 0.06151], [acc 0.94630], [acc_cls 0.88605], [mean_iu 0.75753], [fwavacc 0.90999]
# ====================================================================
# [epoch 128], [iter 10 / 25], [train loss 0.03418]
# [epoch 128], [iter 20 / 25], [train loss 0.03396]
# ====================================================================
# [epoch 128], [val loss 0.06140], [acc 0.94620], [acc_cls 0.88490], [mean_iu 0.75754], [fwavacc 0.90990]
# ====================================================================
# [epoch 129], [iter 10 / 25], [train loss 0.03460]
# [epoch 129], [iter 20 / 25], [train loss 0.03470]
# ====================================================================
# [epoch 129], [val loss 0.06140], [acc 0.94626], [acc_cls 0.88424], [mean_iu 0.75698], [fwavacc 0.90985]
# ====================================================================
# [epoch 130], [iter 10 / 25], [train loss 0.03351]
# [epoch 130], [iter 20 / 25], [train loss 0.03397]
# ====================================================================
# [epoch 130], [val loss 0.06480], [acc 0.94287], [acc_cls 0.88773], [mean_iu 0.75151], [fwavacc 0.90568]
# ====================================================================
# [epoch 131], [iter 10 / 25], [train loss 0.03472]
# [epoch 131], [iter 20 / 25], [train loss 0.03477]
# ====================================================================
# [epoch 131], [val loss 0.06046], [acc 0.94684], [acc_cls 0.88098], [mean_iu 0.75749], [fwavacc 0.91047]
# ====================================================================
# [epoch 132], [iter 10 / 25], [train loss 0.03657]
# [epoch 132], [iter 20 / 25], [train loss 0.03513]
# ====================================================================
# [epoch 132], [val loss 0.06103], [acc 0.94654], [acc_cls 0.88341], [mean_iu 0.75775], [fwavacc 0.91022]
# ====================================================================
# [epoch 133], [iter 10 / 25], [train loss 0.03488]
# [epoch 133], [iter 20 / 25], [train loss 0.03507]
# ====================================================================
# [epoch 133], [val loss 0.05923], [acc 0.94724], [acc_cls 0.87502], [mean_iu 0.75458], [fwavacc 0.91089]
# ====================================================================
# [epoch 134], [iter 10 / 25], [train loss 0.03482]
# [epoch 134], [iter 20 / 25], [train loss 0.03440]
# ====================================================================
# [epoch 134], [val loss 0.06131], [acc 0.94583], [acc_cls 0.88184], [mean_iu 0.75392], [fwavacc 0.90937]
# ====================================================================
# [epoch 135], [iter 10 / 25], [train loss 0.03387]
# [epoch 135], [iter 20 / 25], [train loss 0.03445]
# ====================================================================
# [epoch 135], [val loss 0.05984], [acc 0.94687], [acc_cls 0.87798], [mean_iu 0.75518], [fwavacc 0.91052]
# ====================================================================
# Epoch   135: reducing learning rate of group 0 to 1.0000e-08.
# [epoch 136], [iter 10 / 25], [train loss 0.03492]
# [epoch 136], [iter 20 / 25], [train loss 0.03478]
# ====================================================================
# [epoch 136], [val loss 0.05995], [acc 0.94682], [acc_cls 0.87693], [mean_iu 0.75429], [fwavacc 0.91038]
# ====================================================================
# [epoch 137], [iter 10 / 25], [train loss 0.03418]
# [epoch 137], [iter 20 / 25], [train loss 0.03463]
# ====================================================================
# [epoch 137], [val loss 0.06215], [acc 0.94493], [acc_cls 0.88168], [mean_iu 0.75256], [fwavacc 0.90824]
# ====================================================================
# [epoch 138], [iter 10 / 25], [train loss 0.03478]
# [epoch 138], [iter 20 / 25], [train loss 0.03428]
# ====================================================================
# [epoch 138], [val loss 0.06042], [acc 0.94725], [acc_cls 0.88208], [mean_iu 0.75839], [fwavacc 0.91104]
# ====================================================================
# [epoch 139], [iter 10 / 25], [train loss 0.03490]
# [epoch 139], [iter 20 / 25], [train loss 0.03552]
# ====================================================================
# [epoch 139], [val loss 0.05894], [acc 0.94746], [acc_cls 0.87545], [mean_iu 0.75490], [fwavacc 0.91119]
# ====================================================================
# [epoch 140], [iter 10 / 25], [train loss 0.03422]
# [epoch 140], [iter 20 / 25], [train loss 0.03445]
# ====================================================================
# [epoch 140], [val loss 0.06144], [acc 0.94530], [acc_cls 0.87892], [mean_iu 0.75131], [fwavacc 0.90856]
# ====================================================================
# [epoch 141], [iter 10 / 25], [train loss 0.03501]
# [epoch 141], [iter 20 / 25], [train loss 0.03478]
# ====================================================================
# [epoch 141], [val loss 0.06065], [acc 0.94617], [acc_cls 0.87754], [mean_iu 0.75332], [fwavacc 0.90962]
# ====================================================================
# [epoch 142], [iter 10 / 25], [train loss 0.03477]
# [epoch 142], [iter 20 / 25], [train loss 0.03430]
# ====================================================================
# [epoch 142], [val loss 0.06049], [acc 0.94688], [acc_cls 0.88143], [mean_iu 0.75710], [fwavacc 0.91048]
# ====================================================================
# [epoch 143], [iter 10 / 25], [train loss 0.03443]
# [epoch 143], [iter 20 / 25], [train loss 0.03457]
# ====================================================================
# [epoch 143], [val loss 0.06182], [acc 0.94519], [acc_cls 0.88007], [mean_iu 0.75298], [fwavacc 0.90828]
# ====================================================================
# [epoch 144], [iter 10 / 25], [train loss 0.03576]
# [epoch 144], [iter 20 / 25], [train loss 0.03488]
# ====================================================================
# [epoch 144], [val loss 0.06021], [acc 0.94672], [acc_cls 0.87861], [mean_iu 0.75504], [fwavacc 0.91034]
# ====================================================================
# [epoch 145], [iter 10 / 25], [train loss 0.03419]
# [epoch 145], [iter 20 / 25], [train loss 0.03475]
# ====================================================================
# [epoch 145], [val loss 0.06058], [acc 0.94660], [acc_cls 0.88040], [mean_iu 0.75601], [fwavacc 0.91017]
# ====================================================================
# [epoch 146], [iter 10 / 25], [train loss 0.03473]
# [epoch 146], [iter 20 / 25], [train loss 0.03441]
# ====================================================================
# [epoch 146], [val loss 0.06155], [acc 0.94617], [acc_cls 0.88569], [mean_iu 0.75796], [fwavacc 0.90973]
# ====================================================================
# [epoch 147], [iter 10 / 25], [train loss 0.03384]
# [epoch 147], [iter 20 / 25], [train loss 0.03448]
# ====================================================================
# [epoch 147], [val loss 0.06329], [acc 0.94459], [acc_cls 0.88607], [mean_iu 0.75414], [fwavacc 0.90776]
# ====================================================================
# [epoch 148], [iter 10 / 25], [train loss 0.03505]
# [epoch 148], [iter 20 / 25], [train loss 0.03477]
# ====================================================================
# [epoch 148], [val loss 0.06127], [acc 0.94587], [acc_cls 0.88079], [mean_iu 0.75417], [fwavacc 0.90928]
# ====================================================================
# [epoch 149], [iter 10 / 25], [train loss 0.03475]
# [epoch 149], [iter 20 / 25], [train loss 0.03422]
# ====================================================================
# [epoch 149], [val loss 0.06091], [acc 0.94610], [acc_cls 0.88020], [mean_iu 0.75498], [fwavacc 0.90952]
# ====================================================================
# [epoch 150], [iter 10 / 25], [train loss 0.03315]
# [epoch 150], [iter 20 / 25], [train loss 0.03483]
# ====================================================================
# [epoch 150], [val loss 0.06145], [acc 0.94578], [acc_cls 0.88303], [mean_iu 0.75489], [fwavacc 0.90921]
# ====================================================================

# %%
! tensorboard --logdir=writer_path --host localhost --port 8088
# Out:
# 2020-12-17 17:01:56.793448: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorBoard 2.3.0 at http://localhost:8088/ (Press CTRL+C to quit)
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/concurrent/futures/thread.py", line 33, in _python_exit
#     def _python_exit():
# KeyboardInterrupt

# %% [markdown]
# # Testing

# %%
test_data_path = '/content/drive/My Drive/data/test'
test_set = TestDataset(test_data_path)
test_data_loader = DataLoader(dataset=test_set, num_workers=4, batch_size=batchsize, shuffle=False)
PATH = os.path.join(model_data_path,'Unet_Onelayer', 'Bestmodel_epoch_101'+'.pth')
net = UNet(num_classes = 4).cuda()
net.load_state_dict(torch.load(PATH))
net.eval()
val_loss = AverageMeter()
batchsize=4
learningrate=1e-5


# Loss function and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learningrate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)


for iteration, sample in enumerate(test_data_loader):
    img= sample
    img=img.unsqueeze(1).cuda() # adding 1 channel
    #mask=mask.to(dtype=torch.int64).cuda()# mask should be long type

    outputs = net(img)
    predictions = outputs.data.max(1)[1].squeeze_(1).squeeze_(0).cpu().numpy()
    plt.imshow(predictions[0,...],cmap='gray')
    plt.pause(0.1)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2952: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
