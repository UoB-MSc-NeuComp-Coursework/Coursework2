# %% [markdown]
# # **Initial**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader  # Load the data
from torch.utils.tensorboard import SummaryWriter  # Show the Tensorboard
import cv2
import os
from matplotlib import pyplot as plt
from glob import glob
import random
import numpy as np
from math import ceil

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
def show_image_mask(img, mask, cmap='gray'):  # visualisation
    fig = plt.figure(figsize=(5, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(img, cmap=cmap)
    plt.axis('off')
    plt.subplot(1, 2, 2)
    plt.imshow(mask, cmap=cmap)
    plt.axis('off')
data_dir = '/content/drive/My Drive/data/train'
image = cv2.imread(os.path.join(data_dir,'image','cmr1.png'), cv2.IMREAD_UNCHANGED)
mask = cv2.imread(os.path.join(data_dir,'mask','cmr1_mask.png'), cv2.IMREAD_UNCHANGED)
show_image_mask(image, mask, cmap='gray')
plt.pause(1)
cv2.imwrite(os.path.join('./','cmr1.png'), mask*85)
# Out:
# True

# %% [markdown]
# # **1 DataImport**

# %%
################################################################################
class TrainDataset(data.Dataset):
    def __init__(self, root=''):
        super(TrainDataset, self).__init__()
        self.img_files = glob(os.path.join(root, 'image', '*.png'))
        self.mask_files = []
        for img_path in self.img_files:
            basename = os.path.basename(img_path)
            self.mask_files.append(os.path.join(root, 'mask', basename[:-4] + '_mask.png'))

    def __getitem__(self, index):
        img_path = self.img_files[index]
        mask_path = self.mask_files[index]
        data = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
        label = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)
        return torch.from_numpy(data).float(), torch.from_numpy(label).float()

    def __len__(self):
        return len(self.img_files)


class TestDataset(data.Dataset):
    def __init__(self, root=''):
        super(TestDataset, self).__init__()
        self.img_files = glob(os.path.join(root, 'image', '*.png'))

    def __getitem__(self, index):
        img_path = self.img_files[index]
        data = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
        return torch.from_numpy(data).float()

    def __len__(self):
        return len(self.img_files)
################################################################################

# %% [markdown]
# # **2 CNN Structure**

# %%
################################################################################
#Define a Segmentation Model
class EncoderLayer(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=False):
        super(EncoderLayer, self).__init__()
        layers = [
            nn.Conv2d(in_channels, out_channels, kernel_size=3,padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3,padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        ]
        if dropout:
            layers.append(nn.Dropout())
        layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
        self.encode = nn.Sequential(*layers)

    def forward(self, x):
        return self.encode(x)


class DecoderLayer(nn.Module):
    def __init__(self, in_channels, middle_channels, out_channels):
        super(DecoderLayer, self).__init__()
        self.decode = nn.Sequential(
            nn.Conv2d(in_channels, middle_channels, kernel_size=3,padding=1),
            nn.BatchNorm2d(middle_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(middle_channels, middle_channels, kernel_size=3,padding=1),
            nn.BatchNorm2d(middle_channels),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(middle_channels, out_channels, kernel_size=2, stride=2),
        )

    def forward(self, x):
        return self.decode(x)


def initialize_weights(*models):
    for model in models:
        for module in model.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight)
                if module.bias is not None:
                    module.bias.data.zero_()
            elif isinstance(module, nn.BatchNorm2d):
                module.weight.data.fill_(1)
                module.bias.data.zero_()


class UNet(nn.Module):
    def __init__(self, num_classes):
        super(UNet, self).__init__()
        self.enc1 = EncoderLayer(1, 64)
        self.enc2 = EncoderLayer(64, 128)
        self.enc3 = EncoderLayer(128, 256)
        self.enc4 = EncoderLayer(256, 512, dropout=True)
        self.center = DecoderLayer(512, 1024, 512)
        self.dec4 = DecoderLayer(1024, 512, 256)
        self.dec3 = DecoderLayer(512, 256, 128)
        self.dec2 = DecoderLayer(256, 128, 64)
        self.dec1 = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
        )
        self.final = nn.Conv2d(64, num_classes, kernel_size=1)
        initialize_weights(self)

    def forward(self, x):
        enc1 = self.enc1(x)
        enc2 = self.enc2(enc1)
        enc3 = self.enc3(enc2)
        enc4 = self.enc4(enc3)
        center = self.center(enc4)
        dec4 = self.dec4(torch.cat([center, F.upsample(enc4, center.size()[2:], mode='bilinear')], 1))
        dec3 = self.dec3(torch.cat([dec4, F.upsample(enc3, dec4.size()[2:], mode='bilinear')], 1))
        dec2 = self.dec2(torch.cat([dec3, F.upsample(enc2, dec3.size()[2:], mode='bilinear')], 1))
        dec1 = self.dec1(torch.cat([dec2, F.upsample(enc1, dec2.size()[2:], mode='bilinear')], 1))
        final = self.final(dec1)
        return F.upsample(final, x.size()[2:], mode='bilinear')
################################################################################

# %% [markdown]
# # **4 Functions of Training, Validation**

# %% [markdown]
# ## Parameter Setting

# %%
# Network Established 
net = UNet(num_classes = 4).cuda()


# The Hyperparameter that Optimized
batchsize=4
learningrate=1e-5



# Using decreaseing learning rate tuning
from torch.optim.lr_scheduler import ReduceLROnPlateau
min_learningrate=1e-12
lr_patience=10


# Loss function and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learningrate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
best_val_loss = 0.2

#RMSprop(net.parameters(), lr=learningrate, weight_decay=1e-8, momentum=0.9)




# Data Load
train_data_path = '/content/drive/My Drive/data/train'
train_set = TrainDataset(train_data_path)
training_data_loader = DataLoader(dataset=train_set, num_workers=4, batch_size=batchsize, shuffle=True)
valid_data_path = '/content/drive/My Drive/data/val'
valid_set = TrainDataset(valid_data_path)
valid_data_loader = DataLoader(dataset=valid_set, num_workers=4, batch_size=batchsize, shuffle=False)

model_data_path = '/content/drive/My Drive/data/model'

writer_path = os.path.join(model_data_path,'Unet/log')
# Record training process ( basically for ploting figure )
writer = SummaryWriter(writer_path)

# %% [markdown]
# ## AverageMeter and Validation Func

# %%
# Calculate average value of current batch
class AverageMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


####
def _fast_hist(label_pred, label_true, num_classes):
    mask = (label_true >= 0) & (label_true < num_classes)
    hist = np.bincount(
        num_classes * label_true[mask.cpu().numpy()].cpu().numpy().astype(int)+
        label_pred[mask.cpu().numpy()], 
        minlength=num_classes ** 2).reshape(num_classes, num_classes)
    return hist

###
def evaluate(predictions, gts, num_classes):
    hist = np.zeros((num_classes, num_classes))
    for lp, lt in zip(predictions, gts):
        hist += _fast_hist(lp.flatten(), lt.flatten(), num_classes)
    # axis 0: gt, axis 1: prediction
    acc = np.diag(hist).sum() / hist.sum()
    acc_cls = np.diag(hist) / hist.sum(axis=1)
    acc_cls = np.nanmean(acc_cls)
    iu = np.diag(hist) / (hist.sum(axis=1) + hist.sum(axis=0) - np.diag(hist))
    mean_iu = np.nanmean(iu)
    freq = hist.sum(axis=1) / hist.sum()
    fwavacc = (freq[freq > 0] * iu[freq > 0]).sum()
    return acc, acc_cls, mean_iu, fwavacc

# %% [markdown]
# ## Training Sec

# %%
def train(training_data_loader, net, loss_function, optimizer,epoch):
  # Change model status as Training Mode
    net.train()
    train_loss = AverageMeter()
    curr_iter = (epoch - 1) * len(training_data_loader)
    for iteration, sample in enumerate(training_data_loader):
        img, mask = sample
        img=img.unsqueeze(1).cuda() # adding 1 channel
        mask=mask.cuda()

        N = img.size(0)           # number of batch
        optimizer.zero_grad()     # CLEAR GRADIENT BUFFER
        outputs = net(img)        # FORWARD
        loss = loss_function(outputs, mask.to(dtype=torch.int64)) / N # mask type need to be long
        loss.backward()           # BACKWORD
        optimizer.step()          # UPDATE GRADIENT

        train_loss.update(loss.data.item(),N) # Average loss of this loop
        curr_iter += 1
        writer.add_scalar('train_loss', train_loss.avg, curr_iter)

        if (iteration + 1) % 10 == 0:
            print('[epoch %d], [iter %d / %d], [train loss %.5f]' % (
                  epoch+1, iteration + 1, len(training_data_loader), train_loss.avg
        ))
    return train_loss.avg

# %% [markdown]
# ## Validation sec

# %%
def validation(valid_data_loader, net, loss_function, optimizer, epoch):
    # Model Status as Evaluation Mode
    net.eval()
    val_loss = AverageMeter()
    img_all, mask_all, predictions_all = [], [], []

    for iteration, sample in enumerate(valid_data_loader): 
        img, mask = sample
        img=img.unsqueeze(1).cuda() # adding 1 channel
        mask=mask.to(dtype=torch.int64).cuda()# mask should be long type

        N = img.size(0)           # number of data
        outputs = net(img)        # FORWARD
        # Take max over 1D, return [[max of each row], [index of each max]]
        # Get the Max values index
        predictions = outputs.data.max(1)[1].squeeze_(1).squeeze_(0).cpu().numpy() 

        val_loss.update(loss_function(outputs, mask).data.item()/ N, N)
        
        with torch.no_grad():
            mask.squeeze_(0).cpu().numpy()
        mask_all.append(mask)
        predictions_all.append(predictions)
    # Accuracy, Accuracy of each columns , Mean IU, Frequency Weighted Intersection
    # Acc = Correct/Totall
    # Acc_cls = Accuracy of each class
    # IU is Recall, Mean_IU is mean Recall
    # Fwavacc is frequency times Recall
    acc, acc_cls, mean_iu, fwavacc = evaluate(predictions_all, mask_all, 4)# Number of class=4

    writer.add_scalar('val_loss', val_loss.avg, epoch)
    writer.add_scalar('acc', acc, epoch)
    writer.add_scalar('acc_cls', acc_cls, epoch)
    writer.add_scalar('mean_iu', mean_iu, epoch)
    writer.add_scalar('fwavacc', fwavacc, epoch)
    #writer.add_scalar('lr', optimizer.param_groups[1]['lr'], epoch)
    
    print('====================================================================')
    print('[epoch %d], [val loss %.5f], [acc %.5f], [acc_cls %.5f], [mean_iu %.5f], [fwavacc %.5f]' % (
        epoch+1, val_loss.avg, acc, acc_cls, mean_iu, fwavacc))
    print('====================================================================')

    return val_loss.avg

# %% [markdown]
# # **5 Training and validating**

# %%
# Epochs
epochs=150


#Training and Validation
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=lr_patience, min_lr=min_learningrate, verbose=True)# With Learning Decreasing
for epoch in range(epochs):
    PATH = os.path.join(model_data_path, 'Unet/Bestmodel_epoch_'+ str(epoch)+'.pth')
    train_loss = train(training_data_loader, net, loss_function, optimizer,epoch)
    val_loss = validation(valid_data_loader, net, loss_function, optimizer, epoch)
    # Draw train val map
    writer.add_scalars('train/val loss', {
                                        'train_loss':train_loss,
                                        'val_loss':val_loss}, epoch)
    # Save the best model
    if val_loss < best_val_loss:
        print(f"Model Saved at {PATH}")
        best_val_loss = val_loss
        torch.save(net.state_dict(), PATH)
    scheduler.step(val_loss)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2952: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# [epoch 1], [iter 10 / 25], [train loss 0.40889]
# [epoch 1], [iter 20 / 25], [train loss 0.39701]
# ====================================================================
# [epoch 1], [val loss 0.37867], [acc 0.40707], [acc_cls 0.46218], [mean_iu 0.16298], [fwavacc 0.32615]
# ====================================================================
# [epoch 2], [iter 10 / 25], [train loss 0.36053]
# [epoch 2], [iter 20 / 25], [train loss 0.35144]
# ====================================================================
# [epoch 2], [val loss 0.34964], [acc 0.44247], [acc_cls 0.49605], [mean_iu 0.18660], [fwavacc 0.36151]
# ====================================================================
# [epoch 3], [iter 10 / 25], [train loss 0.32822]
# [epoch 3], [iter 20 / 25], [train loss 0.32318]
# ====================================================================
# [epoch 3], [val loss 0.34414], [acc 0.49104], [acc_cls 0.51619], [mean_iu 0.20787], [fwavacc 0.41059]
# ====================================================================
# [epoch 4], [iter 10 / 25], [train loss 0.30810]
# [epoch 4], [iter 20 / 25], [train loss 0.30148]
# ====================================================================
# [epoch 4], [val loss 0.33041], [acc 0.53805], [acc_cls 0.53785], [mean_iu 0.23304], [fwavacc 0.45844]
# ====================================================================
# [epoch 5], [iter 10 / 25], [train loss 0.27498]
# [epoch 5], [iter 20 / 25], [train loss 0.27033]
# ====================================================================
# [epoch 5], [val loss 0.27448], [acc 0.63346], [acc_cls 0.58680], [mean_iu 0.29687], [fwavacc 0.55533]
# ====================================================================
# [epoch 6], [iter 10 / 25], [train loss 0.24828]
# [epoch 6], [iter 20 / 25], [train loss 0.23306]
# ====================================================================
# [epoch 6], [val loss 0.22226], [acc 0.75567], [acc_cls 0.61311], [mean_iu 0.38868], [fwavacc 0.68018]
# ====================================================================
# [epoch 7], [iter 10 / 25], [train loss 0.20306]
# [epoch 7], [iter 20 / 25], [train loss 0.20177]
# ====================================================================
# [epoch 7], [val loss 0.18938], [acc 0.83642], [acc_cls 0.63766], [mean_iu 0.46059], [fwavacc 0.76356]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_6.pth
# [epoch 8], [iter 10 / 25], [train loss 0.18427]
# [epoch 8], [iter 20 / 25], [train loss 0.17384]
# ====================================================================
# [epoch 8], [val loss 0.17923], [acc 0.85539], [acc_cls 0.67942], [mean_iu 0.48927], [fwavacc 0.78829]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_7.pth
# [epoch 9], [iter 10 / 25], [train loss 0.15484]
# [epoch 9], [iter 20 / 25], [train loss 0.15827]
# ====================================================================
# [epoch 9], [val loss 0.15323], [acc 0.89983], [acc_cls 0.61768], [mean_iu 0.53321], [fwavacc 0.82989]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_8.pth
# [epoch 10], [iter 10 / 25], [train loss 0.14897]
# [epoch 10], [iter 20 / 25], [train loss 0.14297]
# ====================================================================
# [epoch 10], [val loss 0.14664], [acc 0.89302], [acc_cls 0.55451], [mean_iu 0.49715], [fwavacc 0.81522]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_9.pth
# [epoch 11], [iter 10 / 25], [train loss 0.13483]
# [epoch 11], [iter 20 / 25], [train loss 0.13032]
# ====================================================================
# [epoch 11], [val loss 0.13239], [acc 0.91748], [acc_cls 0.67522], [mean_iu 0.59335], [fwavacc 0.85748]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_10.pth
# [epoch 12], [iter 10 / 25], [train loss 0.12344]
# [epoch 12], [iter 20 / 25], [train loss 0.12232]
# ====================================================================
# [epoch 12], [val loss 0.12457], [acc 0.92777], [acc_cls 0.73985], [mean_iu 0.64053], [fwavacc 0.87637]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_11.pth
# [epoch 13], [iter 10 / 25], [train loss 0.11649]
# [epoch 13], [iter 20 / 25], [train loss 0.11343]
# ====================================================================
# [epoch 13], [val loss 0.12247], [acc 0.91155], [acc_cls 0.62619], [mean_iu 0.56695], [fwavacc 0.84517]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_12.pth
# [epoch 14], [iter 10 / 25], [train loss 0.10786]
# [epoch 14], [iter 20 / 25], [train loss 0.10695]
# ====================================================================
# [epoch 14], [val loss 0.11931], [acc 0.90922], [acc_cls 0.61938], [mean_iu 0.55825], [fwavacc 0.84316]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_13.pth
# [epoch 15], [iter 10 / 25], [train loss 0.10295]
# [epoch 15], [iter 20 / 25], [train loss 0.10138]
# ====================================================================
# [epoch 15], [val loss 0.11094], [acc 0.92482], [acc_cls 0.69840], [mean_iu 0.62612], [fwavacc 0.86960]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_14.pth
# [epoch 16], [iter 10 / 25], [train loss 0.09436]
# [epoch 16], [iter 20 / 25], [train loss 0.09275]
# ====================================================================
# [epoch 16], [val loss 0.10944], [acc 0.91887], [acc_cls 0.68331], [mean_iu 0.60705], [fwavacc 0.86202]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_15.pth
# [epoch 17], [iter 10 / 25], [train loss 0.09056]
# [epoch 17], [iter 20 / 25], [train loss 0.09169]
# ====================================================================
# [epoch 17], [val loss 0.10667], [acc 0.92433], [acc_cls 0.72486], [mean_iu 0.63605], [fwavacc 0.87255]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_16.pth
# [epoch 18], [iter 10 / 25], [train loss 0.08650]
# [epoch 18], [iter 20 / 25], [train loss 0.08716]
# ====================================================================
# [epoch 18], [val loss 0.10297], [acc 0.92582], [acc_cls 0.74357], [mean_iu 0.64876], [fwavacc 0.87609]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_17.pth
# [epoch 19], [iter 10 / 25], [train loss 0.08457]
# [epoch 19], [iter 20 / 25], [train loss 0.08328]
# ====================================================================
# [epoch 19], [val loss 0.10087], [acc 0.92357], [acc_cls 0.70967], [mean_iu 0.62290], [fwavacc 0.87118]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_18.pth
# [epoch 20], [iter 10 / 25], [train loss 0.08031]
# [epoch 20], [iter 20 / 25], [train loss 0.08104]
# ====================================================================
# [epoch 20], [val loss 0.10020], [acc 0.92064], [acc_cls 0.66749], [mean_iu 0.59059], [fwavacc 0.86441]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_19.pth
# [epoch 21], [iter 10 / 25], [train loss 0.08040]
# [epoch 21], [iter 20 / 25], [train loss 0.07915]
# ====================================================================
# [epoch 21], [val loss 0.10144], [acc 0.92418], [acc_cls 0.81273], [mean_iu 0.68009], [fwavacc 0.87945]
# ====================================================================
# [epoch 22], [iter 10 / 25], [train loss 0.07970]
# [epoch 22], [iter 20 / 25], [train loss 0.07692]
# ====================================================================
# [epoch 22], [val loss 0.09439], [acc 0.92732], [acc_cls 0.71029], [mean_iu 0.62438], [fwavacc 0.87693]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_21.pth
# [epoch 23], [iter 10 / 25], [train loss 0.07526]
# [epoch 23], [iter 20 / 25], [train loss 0.07423]
# ====================================================================
# [epoch 23], [val loss 0.09371], [acc 0.92758], [acc_cls 0.71406], [mean_iu 0.62541], [fwavacc 0.87740]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_22.pth
# [epoch 24], [iter 10 / 25], [train loss 0.07070]
# [epoch 24], [iter 20 / 25], [train loss 0.07095]
# ====================================================================
# [epoch 24], [val loss 0.09539], [acc 0.91654], [acc_cls 0.65616], [mean_iu 0.57091], [fwavacc 0.85909]
# ====================================================================
# [epoch 25], [iter 10 / 25], [train loss 0.06918]
# [epoch 25], [iter 20 / 25], [train loss 0.07094]
# ====================================================================
# [epoch 25], [val loss 0.09196], [acc 0.92705], [acc_cls 0.73229], [mean_iu 0.63186], [fwavacc 0.87865]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_24.pth
# [epoch 26], [iter 10 / 25], [train loss 0.06839]
# [epoch 26], [iter 20 / 25], [train loss 0.06773]
# ====================================================================
# [epoch 26], [val loss 0.08768], [acc 0.93173], [acc_cls 0.75495], [mean_iu 0.65509], [fwavacc 0.88552]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_25.pth
# [epoch 27], [iter 10 / 25], [train loss 0.06936]
# [epoch 27], [iter 20 / 25], [train loss 0.06728]
# ====================================================================
# [epoch 27], [val loss 0.09174], [acc 0.92106], [acc_cls 0.72548], [mean_iu 0.61908], [fwavacc 0.87090]
# ====================================================================
# [epoch 28], [iter 10 / 25], [train loss 0.06711]
# [epoch 28], [iter 20 / 25], [train loss 0.06734]
# ====================================================================
# [epoch 28], [val loss 0.09066], [acc 0.92045], [acc_cls 0.67176], [mean_iu 0.58165], [fwavacc 0.86676]
# ====================================================================
# [epoch 29], [iter 10 / 25], [train loss 0.06312]
# [epoch 29], [iter 20 / 25], [train loss 0.06325]
# ====================================================================
# [epoch 29], [val loss 0.09107], [acc 0.91860], [acc_cls 0.71722], [mean_iu 0.60688], [fwavacc 0.86867]
# ====================================================================
# [epoch 30], [iter 10 / 25], [train loss 0.06212]
# [epoch 30], [iter 20 / 25], [train loss 0.06299]
# ====================================================================
# [epoch 30], [val loss 0.08407], [acc 0.93423], [acc_cls 0.76138], [mean_iu 0.66011], [fwavacc 0.88947]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_29.pth
# [epoch 31], [iter 10 / 25], [train loss 0.06465]
# [epoch 31], [iter 20 / 25], [train loss 0.06245]
# ====================================================================
# [epoch 31], [val loss 0.08624], [acc 0.92610], [acc_cls 0.73567], [mean_iu 0.62928], [fwavacc 0.87832]
# ====================================================================
# [epoch 32], [iter 10 / 25], [train loss 0.06105]
# [epoch 32], [iter 20 / 25], [train loss 0.06016]
# ====================================================================
# [epoch 32], [val loss 0.08717], [acc 0.92405], [acc_cls 0.76839], [mean_iu 0.64615], [fwavacc 0.87797]
# ====================================================================
# [epoch 33], [iter 10 / 25], [train loss 0.05807]
# [epoch 33], [iter 20 / 25], [train loss 0.05938]
# ====================================================================
# [epoch 33], [val loss 0.08530], [acc 0.92655], [acc_cls 0.75034], [mean_iu 0.63803], [fwavacc 0.87979]
# ====================================================================
# [epoch 34], [iter 10 / 25], [train loss 0.05967]
# [epoch 34], [iter 20 / 25], [train loss 0.05886]
# ====================================================================
# [epoch 34], [val loss 0.08621], [acc 0.92117], [acc_cls 0.72695], [mean_iu 0.61303], [fwavacc 0.87186]
# ====================================================================
# [epoch 35], [iter 10 / 25], [train loss 0.05855]
# [epoch 35], [iter 20 / 25], [train loss 0.05794]
# ====================================================================
# [epoch 35], [val loss 0.08472], [acc 0.92255], [acc_cls 0.69590], [mean_iu 0.59640], [fwavacc 0.87077]
# ====================================================================
# [epoch 36], [iter 10 / 25], [train loss 0.05742]
# [epoch 36], [iter 20 / 25], [train loss 0.05694]
# ====================================================================
# [epoch 36], [val loss 0.08278], [acc 0.92812], [acc_cls 0.76200], [mean_iu 0.64923], [fwavacc 0.88196]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_35.pth
# [epoch 37], [iter 10 / 25], [train loss 0.05532]
# [epoch 37], [iter 20 / 25], [train loss 0.05503]
# ====================================================================
# [epoch 37], [val loss 0.08646], [acc 0.92358], [acc_cls 0.82055], [mean_iu 0.67868], [fwavacc 0.88035]
# ====================================================================
# [epoch 38], [iter 10 / 25], [train loss 0.05636]
# [epoch 38], [iter 20 / 25], [train loss 0.05616]
# ====================================================================
# [epoch 38], [val loss 0.08689], [acc 0.92102], [acc_cls 0.80528], [mean_iu 0.66318], [fwavacc 0.87621]
# ====================================================================
# [epoch 39], [iter 10 / 25], [train loss 0.05397]
# [epoch 39], [iter 20 / 25], [train loss 0.05501]
# ====================================================================
# [epoch 39], [val loss 0.08597], [acc 0.92201], [acc_cls 0.79954], [mean_iu 0.66166], [fwavacc 0.87771]
# ====================================================================
# [epoch 40], [iter 10 / 25], [train loss 0.05367]
# [epoch 40], [iter 20 / 25], [train loss 0.05334]
# ====================================================================
# [epoch 40], [val loss 0.08403], [acc 0.92181], [acc_cls 0.76749], [mean_iu 0.63938], [fwavacc 0.87567]
# ====================================================================
# [epoch 41], [iter 10 / 25], [train loss 0.05123]
# [epoch 41], [iter 20 / 25], [train loss 0.05146]
# ====================================================================
# [epoch 41], [val loss 0.08252], [acc 0.92950], [acc_cls 0.83562], [mean_iu 0.69248], [fwavacc 0.88856]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_40.pth
# [epoch 42], [iter 10 / 25], [train loss 0.05345]
# [epoch 42], [iter 20 / 25], [train loss 0.05229]
# ====================================================================
# [epoch 42], [val loss 0.07979], [acc 0.93047], [acc_cls 0.79745], [mean_iu 0.66740], [fwavacc 0.88837]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_41.pth
# [epoch 43], [iter 10 / 25], [train loss 0.05255]
# [epoch 43], [iter 20 / 25], [train loss 0.05201]
# ====================================================================
# [epoch 43], [val loss 0.08077], [acc 0.92694], [acc_cls 0.79324], [mean_iu 0.66050], [fwavacc 0.88330]
# ====================================================================
# [epoch 44], [iter 10 / 25], [train loss 0.05341]
# [epoch 44], [iter 20 / 25], [train loss 0.05179]
# ====================================================================
# [epoch 44], [val loss 0.07740], [acc 0.93008], [acc_cls 0.77112], [mean_iu 0.65199], [fwavacc 0.88576]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_43.pth
# [epoch 45], [iter 10 / 25], [train loss 0.05023]
# [epoch 45], [iter 20 / 25], [train loss 0.04981]
# ====================================================================
# [epoch 45], [val loss 0.07729], [acc 0.93234], [acc_cls 0.82170], [mean_iu 0.69034], [fwavacc 0.89056]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_44.pth
# [epoch 46], [iter 10 / 25], [train loss 0.04936]
# [epoch 46], [iter 20 / 25], [train loss 0.04967]
# ====================================================================
# [epoch 46], [val loss 0.07911], [acc 0.92795], [acc_cls 0.82049], [mean_iu 0.68272], [fwavacc 0.88542]
# ====================================================================
# [epoch 47], [iter 10 / 25], [train loss 0.04766]
# [epoch 47], [iter 20 / 25], [train loss 0.04822]
# ====================================================================
# [epoch 47], [val loss 0.08084], [acc 0.92811], [acc_cls 0.83227], [mean_iu 0.68729], [fwavacc 0.88695]
# ====================================================================
# [epoch 48], [iter 10 / 25], [train loss 0.04782]
# [epoch 48], [iter 20 / 25], [train loss 0.04828]
# ====================================================================
# [epoch 48], [val loss 0.08244], [acc 0.92320], [acc_cls 0.81254], [mean_iu 0.66822], [fwavacc 0.88024]
# ====================================================================
# [epoch 49], [iter 10 / 25], [train loss 0.04895]
# [epoch 49], [iter 20 / 25], [train loss 0.04758]
# ====================================================================
# [epoch 49], [val loss 0.07677], [acc 0.93268], [acc_cls 0.83968], [mean_iu 0.69994], [fwavacc 0.89247]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_48.pth
# [epoch 50], [iter 10 / 25], [train loss 0.04873]
# [epoch 50], [iter 20 / 25], [train loss 0.04797]
# ====================================================================
# [epoch 50], [val loss 0.07540], [acc 0.93162], [acc_cls 0.80579], [mean_iu 0.67305], [fwavacc 0.88960]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_49.pth
# [epoch 51], [iter 10 / 25], [train loss 0.04653]
# [epoch 51], [iter 20 / 25], [train loss 0.04629]
# ====================================================================
# [epoch 51], [val loss 0.07579], [acc 0.92702], [acc_cls 0.73262], [mean_iu 0.62310], [fwavacc 0.87866]
# ====================================================================
# [epoch 52], [iter 10 / 25], [train loss 0.04627]
# [epoch 52], [iter 20 / 25], [train loss 0.04643]
# ====================================================================
# [epoch 52], [val loss 0.07563], [acc 0.92820], [acc_cls 0.72200], [mean_iu 0.62412], [fwavacc 0.87857]
# ====================================================================
# [epoch 53], [iter 10 / 25], [train loss 0.04467]
# [epoch 53], [iter 20 / 25], [train loss 0.04496]
# ====================================================================
# [epoch 53], [val loss 0.07699], [acc 0.92622], [acc_cls 0.78616], [mean_iu 0.65048], [fwavacc 0.88284]
# ====================================================================
# [epoch 54], [iter 10 / 25], [train loss 0.04551]
# [epoch 54], [iter 20 / 25], [train loss 0.04557]
# ====================================================================
# [epoch 54], [val loss 0.07377], [acc 0.93170], [acc_cls 0.81333], [mean_iu 0.68411], [fwavacc 0.88933]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_53.pth
# [epoch 55], [iter 10 / 25], [train loss 0.04482]
# [epoch 55], [iter 20 / 25], [train loss 0.04443]
# ====================================================================
# [epoch 55], [val loss 0.07991], [acc 0.92592], [acc_cls 0.85074], [mean_iu 0.69653], [fwavacc 0.88472]
# ====================================================================
# [epoch 56], [iter 10 / 25], [train loss 0.04467]
# [epoch 56], [iter 20 / 25], [train loss 0.04477]
# ====================================================================
# [epoch 56], [val loss 0.08367], [acc 0.92189], [acc_cls 0.84476], [mean_iu 0.68575], [fwavacc 0.87962]
# ====================================================================
# [epoch 57], [iter 10 / 25], [train loss 0.04458]
# [epoch 57], [iter 20 / 25], [train loss 0.04344]
# ====================================================================
# [epoch 57], [val loss 0.07418], [acc 0.93128], [acc_cls 0.82799], [mean_iu 0.68649], [fwavacc 0.89020]
# ====================================================================
# [epoch 58], [iter 10 / 25], [train loss 0.04489]
# [epoch 58], [iter 20 / 25], [train loss 0.04361]
# ====================================================================
# [epoch 58], [val loss 0.07414], [acc 0.93044], [acc_cls 0.82320], [mean_iu 0.68177], [fwavacc 0.88961]
# ====================================================================
# [epoch 59], [iter 10 / 25], [train loss 0.04304]
# [epoch 59], [iter 20 / 25], [train loss 0.04279]
# ====================================================================
# [epoch 59], [val loss 0.07159], [acc 0.93268], [acc_cls 0.77966], [mean_iu 0.66141], [fwavacc 0.88934]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_58.pth
# [epoch 60], [iter 10 / 25], [train loss 0.04119]
# [epoch 60], [iter 20 / 25], [train loss 0.04188]
# ====================================================================
# [epoch 60], [val loss 0.07448], [acc 0.92822], [acc_cls 0.81583], [mean_iu 0.67910], [fwavacc 0.88544]
# ====================================================================
# [epoch 61], [iter 10 / 25], [train loss 0.04247]
# [epoch 61], [iter 20 / 25], [train loss 0.04334]
# ====================================================================
# [epoch 61], [val loss 0.06985], [acc 0.93495], [acc_cls 0.79806], [mean_iu 0.68685], [fwavacc 0.89082]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_60.pth
# [epoch 62], [iter 10 / 25], [train loss 0.04160]
# [epoch 62], [iter 20 / 25], [train loss 0.04090]
# ====================================================================
# [epoch 62], [val loss 0.07869], [acc 0.92607], [acc_cls 0.85398], [mean_iu 0.70059], [fwavacc 0.88516]
# ====================================================================
# [epoch 63], [iter 10 / 25], [train loss 0.04078]
# [epoch 63], [iter 20 / 25], [train loss 0.04152]
# ====================================================================
# [epoch 63], [val loss 0.07412], [acc 0.92835], [acc_cls 0.80707], [mean_iu 0.67115], [fwavacc 0.88560]
# ====================================================================
# [epoch 64], [iter 10 / 25], [train loss 0.04017]
# [epoch 64], [iter 20 / 25], [train loss 0.04048]
# ====================================================================
# [epoch 64], [val loss 0.07559], [acc 0.92637], [acc_cls 0.82322], [mean_iu 0.67980], [fwavacc 0.88411]
# ====================================================================
# [epoch 65], [iter 10 / 25], [train loss 0.04020]
# [epoch 65], [iter 20 / 25], [train loss 0.03993]
# ====================================================================
# [epoch 65], [val loss 0.06426], [acc 0.94148], [acc_cls 0.81439], [mean_iu 0.70180], [fwavacc 0.90169]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_64.pth
# [epoch 66], [iter 10 / 25], [train loss 0.03973]
# [epoch 66], [iter 20 / 25], [train loss 0.03927]
# ====================================================================
# [epoch 66], [val loss 0.07271], [acc 0.92793], [acc_cls 0.80074], [mean_iu 0.66488], [fwavacc 0.88507]
# ====================================================================
# [epoch 67], [iter 10 / 25], [train loss 0.03979]
# [epoch 67], [iter 20 / 25], [train loss 0.03906]
# ====================================================================
# [epoch 67], [val loss 0.06904], [acc 0.93496], [acc_cls 0.83216], [mean_iu 0.69762], [fwavacc 0.89493]
# ====================================================================
# [epoch 68], [iter 10 / 25], [train loss 0.03864]
# [epoch 68], [iter 20 / 25], [train loss 0.03840]
# ====================================================================
# [epoch 68], [val loss 0.06563], [acc 0.93705], [acc_cls 0.77789], [mean_iu 0.66971], [fwavacc 0.89387]
# ====================================================================
# [epoch 69], [iter 10 / 25], [train loss 0.03809]
# [epoch 69], [iter 20 / 25], [train loss 0.03786]
# ====================================================================
# [epoch 69], [val loss 0.06590], [acc 0.93639], [acc_cls 0.79502], [mean_iu 0.68082], [fwavacc 0.89393]
# ====================================================================
# [epoch 70], [iter 10 / 25], [train loss 0.03815]
# [epoch 70], [iter 20 / 25], [train loss 0.03774]
# ====================================================================
# [epoch 70], [val loss 0.06831], [acc 0.93269], [acc_cls 0.79177], [mean_iu 0.66651], [fwavacc 0.88992]
# ====================================================================
# [epoch 71], [iter 10 / 25], [train loss 0.03730]
# [epoch 71], [iter 20 / 25], [train loss 0.03763]
# ====================================================================
# [epoch 71], [val loss 0.06809], [acc 0.93217], [acc_cls 0.78670], [mean_iu 0.66785], [fwavacc 0.88823]
# ====================================================================
# [epoch 72], [iter 10 / 25], [train loss 0.03666]
# [epoch 72], [iter 20 / 25], [train loss 0.03682]
# ====================================================================
# [epoch 72], [val loss 0.06645], [acc 0.93630], [acc_cls 0.81104], [mean_iu 0.69254], [fwavacc 0.89458]
# ====================================================================
# [epoch 73], [iter 10 / 25], [train loss 0.03666]
# [epoch 73], [iter 20 / 25], [train loss 0.03675]
# ====================================================================
# [epoch 73], [val loss 0.07385], [acc 0.92909], [acc_cls 0.85648], [mean_iu 0.70831], [fwavacc 0.88856]
# ====================================================================
# [epoch 74], [iter 10 / 25], [train loss 0.03822]
# [epoch 74], [iter 20 / 25], [train loss 0.03770]
# ====================================================================
# [epoch 74], [val loss 0.06518], [acc 0.93751], [acc_cls 0.82873], [mean_iu 0.70228], [fwavacc 0.89750]
# ====================================================================
# [epoch 75], [iter 10 / 25], [train loss 0.03523]
# [epoch 75], [iter 20 / 25], [train loss 0.03575]
# ====================================================================
# [epoch 75], [val loss 0.06365], [acc 0.93856], [acc_cls 0.79670], [mean_iu 0.68668], [fwavacc 0.89671]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_74.pth
# [epoch 76], [iter 10 / 25], [train loss 0.03775]
# [epoch 76], [iter 20 / 25], [train loss 0.03730]
# ====================================================================
# [epoch 76], [val loss 0.05994], [acc 0.94387], [acc_cls 0.80307], [mean_iu 0.70190], [fwavacc 0.90382]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_75.pth
# [epoch 77], [iter 10 / 25], [train loss 0.03599]
# [epoch 77], [iter 20 / 25], [train loss 0.03628]
# ====================================================================
# [epoch 77], [val loss 0.06476], [acc 0.93880], [acc_cls 0.84232], [mean_iu 0.71730], [fwavacc 0.89954]
# ====================================================================
# [epoch 78], [iter 10 / 25], [train loss 0.03604]
# [epoch 78], [iter 20 / 25], [train loss 0.03672]
# ====================================================================
# [epoch 78], [val loss 0.06297], [acc 0.93931], [acc_cls 0.80489], [mean_iu 0.69409], [fwavacc 0.89816]
# ====================================================================
# [epoch 79], [iter 10 / 25], [train loss 0.03535]
# [epoch 79], [iter 20 / 25], [train loss 0.03491]
# ====================================================================
# [epoch 79], [val loss 0.06506], [acc 0.93573], [acc_cls 0.82103], [mean_iu 0.69787], [fwavacc 0.89406]
# ====================================================================
# [epoch 80], [iter 10 / 25], [train loss 0.03488]
# [epoch 80], [iter 20 / 25], [train loss 0.03482]
# ====================================================================
# [epoch 80], [val loss 0.06136], [acc 0.94114], [acc_cls 0.81425], [mean_iu 0.70435], [fwavacc 0.90071]
# ====================================================================
# [epoch 81], [iter 10 / 25], [train loss 0.03282]
# [epoch 81], [iter 20 / 25], [train loss 0.03383]
# ====================================================================
# [epoch 81], [val loss 0.06683], [acc 0.93379], [acc_cls 0.83709], [mean_iu 0.70064], [fwavacc 0.89302]
# ====================================================================
# [epoch 82], [iter 10 / 25], [train loss 0.03324]
# [epoch 82], [iter 20 / 25], [train loss 0.03377]
# ====================================================================
# [epoch 82], [val loss 0.06345], [acc 0.93727], [acc_cls 0.81789], [mean_iu 0.69972], [fwavacc 0.89574]
# ====================================================================
# [epoch 83], [iter 10 / 25], [train loss 0.03444]
# [epoch 83], [iter 20 / 25], [train loss 0.03382]
# ====================================================================
# [epoch 83], [val loss 0.06362], [acc 0.93785], [acc_cls 0.83746], [mean_iu 0.71386], [fwavacc 0.89760]
# ====================================================================
# [epoch 84], [iter 10 / 25], [train loss 0.03381]
# [epoch 84], [iter 20 / 25], [train loss 0.03371]
# ====================================================================
# [epoch 84], [val loss 0.06940], [acc 0.93013], [acc_cls 0.85090], [mean_iu 0.70769], [fwavacc 0.88920]
# ====================================================================
# [epoch 85], [iter 10 / 25], [train loss 0.03288]
# [epoch 85], [iter 20 / 25], [train loss 0.03344]
# ====================================================================
# [epoch 85], [val loss 0.06318], [acc 0.93629], [acc_cls 0.82162], [mean_iu 0.69800], [fwavacc 0.89537]
# ====================================================================
# [epoch 86], [iter 10 / 25], [train loss 0.03349]
# [epoch 86], [iter 20 / 25], [train loss 0.03309]
# ====================================================================
# [epoch 86], [val loss 0.06055], [acc 0.94058], [acc_cls 0.84013], [mean_iu 0.71966], [fwavacc 0.90152]
# ====================================================================
# [epoch 87], [iter 10 / 25], [train loss 0.03298]
# [epoch 87], [iter 20 / 25], [train loss 0.03293]
# ====================================================================
# [epoch 87], [val loss 0.06075], [acc 0.94147], [acc_cls 0.84131], [mean_iu 0.72006], [fwavacc 0.90307]
# ====================================================================
# Epoch    87: reducing learning rate of group 0 to 1.0000e-06.
# [epoch 88], [iter 10 / 25], [train loss 0.03269]
# [epoch 88], [iter 20 / 25], [train loss 0.03275]
# ====================================================================
# [epoch 88], [val loss 0.06048], [acc 0.94072], [acc_cls 0.83232], [mean_iu 0.71273], [fwavacc 0.90165]
# ====================================================================
# [epoch 89], [iter 10 / 25], [train loss 0.03192]
# [epoch 89], [iter 20 / 25], [train loss 0.03180]
# ====================================================================
# [epoch 89], [val loss 0.06178], [acc 0.94002], [acc_cls 0.84558], [mean_iu 0.72009], [fwavacc 0.90129]
# ====================================================================
# [epoch 90], [iter 10 / 25], [train loss 0.03218]
# [epoch 90], [iter 20 / 25], [train loss 0.03241]
# ====================================================================
# [epoch 90], [val loss 0.06078], [acc 0.94149], [acc_cls 0.84584], [mean_iu 0.72426], [fwavacc 0.90314]
# ====================================================================
# [epoch 91], [iter 10 / 25], [train loss 0.03315]
# [epoch 91], [iter 20 / 25], [train loss 0.03220]
# ====================================================================
# [epoch 91], [val loss 0.06113], [acc 0.93954], [acc_cls 0.83931], [mean_iu 0.71544], [fwavacc 0.90041]
# ====================================================================
# [epoch 92], [iter 10 / 25], [train loss 0.03134]
# [epoch 92], [iter 20 / 25], [train loss 0.03191]
# ====================================================================
# [epoch 92], [val loss 0.06352], [acc 0.93689], [acc_cls 0.84667], [mean_iu 0.71597], [fwavacc 0.89760]
# ====================================================================
# [epoch 93], [iter 10 / 25], [train loss 0.03103]
# [epoch 93], [iter 20 / 25], [train loss 0.03180]
# ====================================================================
# [epoch 93], [val loss 0.06447], [acc 0.93612], [acc_cls 0.84729], [mean_iu 0.71485], [fwavacc 0.89662]
# ====================================================================
# [epoch 94], [iter 10 / 25], [train loss 0.03130]
# [epoch 94], [iter 20 / 25], [train loss 0.03199]
# ====================================================================
# [epoch 94], [val loss 0.06283], [acc 0.93843], [acc_cls 0.84180], [mean_iu 0.71627], [fwavacc 0.89925]
# ====================================================================
# [epoch 95], [iter 10 / 25], [train loss 0.03155]
# [epoch 95], [iter 20 / 25], [train loss 0.03169]
# ====================================================================
# [epoch 95], [val loss 0.06072], [acc 0.94066], [acc_cls 0.83832], [mean_iu 0.71621], [fwavacc 0.90173]
# ====================================================================
# [epoch 96], [iter 10 / 25], [train loss 0.03137]
# [epoch 96], [iter 20 / 25], [train loss 0.03178]
# ====================================================================
# [epoch 96], [val loss 0.06287], [acc 0.93757], [acc_cls 0.83795], [mean_iu 0.70939], [fwavacc 0.89809]
# ====================================================================
# [epoch 97], [iter 10 / 25], [train loss 0.03196]
# [epoch 97], [iter 20 / 25], [train loss 0.03178]
# ====================================================================
# [epoch 97], [val loss 0.06133], [acc 0.93944], [acc_cls 0.83491], [mean_iu 0.71165], [fwavacc 0.90017]
# ====================================================================
# [epoch 98], [iter 10 / 25], [train loss 0.03291]
# [epoch 98], [iter 20 / 25], [train loss 0.03231]
# ====================================================================
# [epoch 98], [val loss 0.06133], [acc 0.94004], [acc_cls 0.84372], [mean_iu 0.71879], [fwavacc 0.90129]
# ====================================================================
# Epoch    98: reducing learning rate of group 0 to 1.0000e-07.
# [epoch 99], [iter 10 / 25], [train loss 0.03182]
# [epoch 99], [iter 20 / 25], [train loss 0.03223]
# ====================================================================
# [epoch 99], [val loss 0.06442], [acc 0.93636], [acc_cls 0.84433], [mean_iu 0.71176], [fwavacc 0.89702]
# ====================================================================
# [epoch 100], [iter 10 / 25], [train loss 0.03082]
# [epoch 100], [iter 20 / 25], [train loss 0.03108]
# ====================================================================
# [epoch 100], [val loss 0.06469], [acc 0.93643], [acc_cls 0.85010], [mean_iu 0.71579], [fwavacc 0.89724]
# ====================================================================
# [epoch 101], [iter 10 / 25], [train loss 0.03156]
# [epoch 101], [iter 20 / 25], [train loss 0.03145]
# ====================================================================
# [epoch 101], [val loss 0.06188], [acc 0.93911], [acc_cls 0.84369], [mean_iu 0.71848], [fwavacc 0.90008]
# ====================================================================
# [epoch 102], [iter 10 / 25], [train loss 0.03206]
# [epoch 102], [iter 20 / 25], [train loss 0.03169]
# ====================================================================
# [epoch 102], [val loss 0.06141], [acc 0.93887], [acc_cls 0.83707], [mean_iu 0.71292], [fwavacc 0.89944]
# ====================================================================
# [epoch 103], [iter 10 / 25], [train loss 0.03094]
# [epoch 103], [iter 20 / 25], [train loss 0.03184]
# ====================================================================
# [epoch 103], [val loss 0.06162], [acc 0.93933], [acc_cls 0.84004], [mean_iu 0.71519], [fwavacc 0.90018]
# ====================================================================
# [epoch 104], [iter 10 / 25], [train loss 0.03218]
# [epoch 104], [iter 20 / 25], [train loss 0.03171]
# ====================================================================
# [epoch 104], [val loss 0.06281], [acc 0.93806], [acc_cls 0.84191], [mean_iu 0.71368], [fwavacc 0.89878]
# ====================================================================
# [epoch 105], [iter 10 / 25], [train loss 0.03169]
# [epoch 105], [iter 20 / 25], [train loss 0.03129]
# ====================================================================
# [epoch 105], [val loss 0.06170], [acc 0.93850], [acc_cls 0.83674], [mean_iu 0.71067], [fwavacc 0.89927]
# ====================================================================
# [epoch 106], [iter 10 / 25], [train loss 0.03235]
# [epoch 106], [iter 20 / 25], [train loss 0.03163]
# ====================================================================
# [epoch 106], [val loss 0.06066], [acc 0.94004], [acc_cls 0.83830], [mean_iu 0.71658], [fwavacc 0.90089]
# ====================================================================
# [epoch 107], [iter 10 / 25], [train loss 0.03113]
# [epoch 107], [iter 20 / 25], [train loss 0.03130]
# ====================================================================
# [epoch 107], [val loss 0.06115], [acc 0.93937], [acc_cls 0.83812], [mean_iu 0.71510], [fwavacc 0.90015]
# ====================================================================
# [epoch 108], [iter 10 / 25], [train loss 0.03195]
# [epoch 108], [iter 20 / 25], [train loss 0.03181]
# ====================================================================
# [epoch 108], [val loss 0.06322], [acc 0.93695], [acc_cls 0.83763], [mean_iu 0.70996], [fwavacc 0.89724]
# ====================================================================
# [epoch 109], [iter 10 / 25], [train loss 0.03212]
# [epoch 109], [iter 20 / 25], [train loss 0.03164]
# ====================================================================
# [epoch 109], [val loss 0.06254], [acc 0.93764], [acc_cls 0.83825], [mean_iu 0.71120], [fwavacc 0.89807]
# ====================================================================
# Epoch   109: reducing learning rate of group 0 to 1.0000e-08.
# [epoch 110], [iter 10 / 25], [train loss 0.03234]
# [epoch 110], [iter 20 / 25], [train loss 0.03211]
# ====================================================================
# [epoch 110], [val loss 0.06183], [acc 0.93857], [acc_cls 0.83797], [mean_iu 0.71340], [fwavacc 0.89919]
# ====================================================================
# [epoch 111], [iter 10 / 25], [train loss 0.03278]
# [epoch 111], [iter 20 / 25], [train loss 0.03236]
# ====================================================================
# [epoch 111], [val loss 0.06257], [acc 0.93809], [acc_cls 0.84044], [mean_iu 0.71295], [fwavacc 0.89878]
# ====================================================================
# [epoch 112], [iter 10 / 25], [train loss 0.03145]
# [epoch 112], [iter 20 / 25], [train loss 0.03157]
# ====================================================================
# [epoch 112], [val loss 0.06259], [acc 0.93806], [acc_cls 0.84334], [mean_iu 0.71537], [fwavacc 0.89893]
# ====================================================================
# [epoch 113], [iter 10 / 25], [train loss 0.03290]
# [epoch 113], [iter 20 / 25], [train loss 0.03233]
# ====================================================================
# [epoch 113], [val loss 0.06220], [acc 0.93810], [acc_cls 0.83699], [mean_iu 0.71030], [fwavacc 0.89858]
# ====================================================================
# [epoch 114], [iter 10 / 25], [train loss 0.03232]
# [epoch 114], [iter 20 / 25], [train loss 0.03165]
# ====================================================================
# [epoch 114], [val loss 0.06125], [acc 0.93889], [acc_cls 0.83315], [mean_iu 0.71096], [fwavacc 0.89919]
# ====================================================================
# [epoch 115], [iter 10 / 25], [train loss 0.03252]
# [epoch 115], [iter 20 / 25], [train loss 0.03259]
# ====================================================================
# [epoch 115], [val loss 0.06097], [acc 0.93901], [acc_cls 0.83254], [mean_iu 0.70901], [fwavacc 0.89945]
# ====================================================================
# [epoch 116], [iter 10 / 25], [train loss 0.03129]
# [epoch 116], [iter 20 / 25], [train loss 0.03155]
# ====================================================================
# [epoch 116], [val loss 0.06306], [acc 0.93759], [acc_cls 0.84161], [mean_iu 0.71308], [fwavacc 0.89820]
# ====================================================================
# [epoch 117], [iter 10 / 25], [train loss 0.03233]
# [epoch 117], [iter 20 / 25], [train loss 0.03242]
# ====================================================================
# [epoch 117], [val loss 0.05952], [acc 0.94049], [acc_cls 0.82830], [mean_iu 0.71065], [fwavacc 0.90089]
# ====================================================================
# Model Saved at /content/drive/My Drive/data/model/Unet/Bestmodel_epoch_116.pth
# [epoch 118], [iter 10 / 25], [train loss 0.03165]
# [epoch 118], [iter 20 / 25], [train loss 0.03189]
# ====================================================================
# [epoch 118], [val loss 0.06206], [acc 0.93802], [acc_cls 0.83863], [mean_iu 0.71225], [fwavacc 0.89851]
# ====================================================================
# [epoch 119], [iter 10 / 25], [train loss 0.03188]
# [epoch 119], [iter 20 / 25], [train loss 0.03157]
# ====================================================================
# [epoch 119], [val loss 0.06167], [acc 0.93956], [acc_cls 0.84124], [mean_iu 0.71578], [fwavacc 0.90052]
# ====================================================================
# [epoch 120], [iter 10 / 25], [train loss 0.03154]
# [epoch 120], [iter 20 / 25], [train loss 0.03137]
# ====================================================================
# [epoch 120], [val loss 0.06233], [acc 0.93821], [acc_cls 0.83873], [mean_iu 0.71218], [fwavacc 0.89880]
# ====================================================================
# [epoch 121], [iter 10 / 25], [train loss 0.03116]
# [epoch 121], [iter 20 / 25], [train loss 0.03173]
# ====================================================================
# [epoch 121], [val loss 0.06324], [acc 0.93729], [acc_cls 0.84000], [mean_iu 0.71217], [fwavacc 0.89770]
# ====================================================================
# [epoch 122], [iter 10 / 25], [train loss 0.03142]
# [epoch 122], [iter 20 / 25], [train loss 0.03107]
# ====================================================================
# [epoch 122], [val loss 0.06332], [acc 0.93685], [acc_cls 0.84321], [mean_iu 0.71259], [fwavacc 0.89748]
# ====================================================================
# [epoch 123], [iter 10 / 25], [train loss 0.03126]
# [epoch 123], [iter 20 / 25], [train loss 0.03154]
# ====================================================================
# [epoch 123], [val loss 0.06327], [acc 0.93748], [acc_cls 0.84451], [mean_iu 0.71524], [fwavacc 0.89822]
# ====================================================================
# [epoch 124], [iter 10 / 25], [train loss 0.03200]
# [epoch 124], [iter 20 / 25], [train loss 0.03194]
# ====================================================================
# [epoch 124], [val loss 0.06194], [acc 0.93869], [acc_cls 0.84165], [mean_iu 0.71611], [fwavacc 0.89948]
# ====================================================================
# [epoch 125], [iter 10 / 25], [train loss 0.03249]
# [epoch 125], [iter 20 / 25], [train loss 0.03195]
# ====================================================================
# [epoch 125], [val loss 0.06222], [acc 0.93838], [acc_cls 0.84277], [mean_iu 0.71561], [fwavacc 0.89930]
# ====================================================================
# [epoch 126], [iter 10 / 25], [train loss 0.03188]
# [epoch 126], [iter 20 / 25], [train loss 0.03158]
# ====================================================================
# [epoch 126], [val loss 0.06343], [acc 0.93728], [acc_cls 0.84402], [mean_iu 0.71429], [fwavacc 0.89801]
# ====================================================================
# [epoch 127], [iter 10 / 25], [train loss 0.03170]
# [epoch 127], [iter 20 / 25], [train loss 0.03179]
# ====================================================================
# [epoch 127], [val loss 0.06144], [acc 0.93926], [acc_cls 0.83829], [mean_iu 0.71462], [fwavacc 0.90004]
# ====================================================================
# [epoch 128], [iter 10 / 25], [train loss 0.03065]
# [epoch 128], [iter 20 / 25], [train loss 0.03120]
# ====================================================================
# [epoch 128], [val loss 0.06386], [acc 0.93712], [acc_cls 0.84924], [mean_iu 0.71730], [fwavacc 0.89798]
# ====================================================================
# [epoch 129], [iter 10 / 25], [train loss 0.03233]
# [epoch 129], [iter 20 / 25], [train loss 0.03146]
# ====================================================================
# [epoch 129], [val loss 0.06236], [acc 0.93765], [acc_cls 0.83734], [mean_iu 0.71094], [fwavacc 0.89804]
# ====================================================================
# [epoch 130], [iter 10 / 25], [train loss 0.03221]
# [epoch 130], [iter 20 / 25], [train loss 0.03164]
# ====================================================================
# [epoch 130], [val loss 0.06118], [acc 0.93979], [acc_cls 0.83916], [mean_iu 0.71696], [fwavacc 0.90074]
# ====================================================================
# [epoch 131], [iter 10 / 25], [train loss 0.03204]
# [epoch 131], [iter 20 / 25], [train loss 0.03129]
# ====================================================================
# [epoch 131], [val loss 0.06198], [acc 0.93827], [acc_cls 0.83787], [mean_iu 0.71242], [fwavacc 0.89878]
# ====================================================================
# [epoch 132], [iter 10 / 25], [train loss 0.03215]
# [epoch 132], [iter 20 / 25], [train loss 0.03162]
# ====================================================================
# [epoch 132], [val loss 0.06198], [acc 0.93805], [acc_cls 0.83508], [mean_iu 0.70955], [fwavacc 0.89836]
# ====================================================================
# [epoch 133], [iter 10 / 25], [train loss 0.03250]
# [epoch 133], [iter 20 / 25], [train loss 0.03173]
# ====================================================================
# [epoch 133], [val loss 0.05962], [acc 0.94166], [acc_cls 0.83671], [mean_iu 0.71825], [fwavacc 0.90273]
# ====================================================================
# [epoch 134], [iter 10 / 25], [train loss 0.03146]
# [epoch 134], [iter 20 / 25], [train loss 0.03236]
# ====================================================================
# [epoch 134], [val loss 0.05989], [acc 0.94132], [acc_cls 0.83747], [mean_iu 0.71831], [fwavacc 0.90238]
# ====================================================================
# [epoch 135], [iter 10 / 25], [train loss 0.03132]
# [epoch 135], [iter 20 / 25], [train loss 0.03152]
# ====================================================================
# [epoch 135], [val loss 0.06068], [acc 0.94038], [acc_cls 0.83713], [mean_iu 0.71666], [fwavacc 0.90125]
# ====================================================================
# [epoch 136], [iter 10 / 25], [train loss 0.03048]
# [epoch 136], [iter 20 / 25], [train loss 0.03118]
# ====================================================================
# [epoch 136], [val loss 0.06526], [acc 0.93564], [acc_cls 0.84685], [mean_iu 0.71300], [fwavacc 0.89617]
# ====================================================================
# [epoch 137], [iter 10 / 25], [train loss 0.03202]
# [epoch 137], [iter 20 / 25], [train loss 0.03188]
# ====================================================================
# [epoch 137], [val loss 0.06285], [acc 0.93790], [acc_cls 0.84203], [mean_iu 0.71404], [fwavacc 0.89856]
# ====================================================================
# [epoch 138], [iter 10 / 25], [train loss 0.03170]
# [epoch 138], [iter 20 / 25], [train loss 0.03187]
# ====================================================================
# [epoch 138], [val loss 0.06061], [acc 0.93993], [acc_cls 0.83764], [mean_iu 0.71534], [fwavacc 0.90082]
# ====================================================================
# [epoch 139], [iter 10 / 25], [train loss 0.03198]
# [epoch 139], [iter 20 / 25], [train loss 0.03145]
# ====================================================================
# [epoch 139], [val loss 0.06169], [acc 0.93860], [acc_cls 0.83421], [mean_iu 0.71073], [fwavacc 0.89884]
# ====================================================================
# [epoch 140], [iter 10 / 25], [train loss 0.03040]
# [epoch 140], [iter 20 / 25], [train loss 0.03217]
# ====================================================================
# [epoch 140], [val loss 0.06284], [acc 0.93742], [acc_cls 0.83838], [mean_iu 0.71091], [fwavacc 0.89777]
# ====================================================================
# [epoch 141], [iter 10 / 25], [train loss 0.03245]
# [epoch 141], [iter 20 / 25], [train loss 0.03187]
# ====================================================================
# [epoch 141], [val loss 0.06273], [acc 0.93785], [acc_cls 0.84423], [mean_iu 0.71614], [fwavacc 0.89859]
# ====================================================================
# [epoch 142], [iter 10 / 25], [train loss 0.03183]
# [epoch 142], [iter 20 / 25], [train loss 0.03141]
# ====================================================================
# [epoch 142], [val loss 0.06301], [acc 0.93792], [acc_cls 0.84346], [mean_iu 0.71480], [fwavacc 0.89869]
# ====================================================================
# [epoch 143], [iter 10 / 25], [train loss 0.03133]
# [epoch 143], [iter 20 / 25], [train loss 0.03170]
# ====================================================================
# [epoch 143], [val loss 0.06008], [acc 0.94049], [acc_cls 0.83465], [mean_iu 0.71478], [fwavacc 0.90133]
# ====================================================================
# [epoch 144], [iter 10 / 25], [train loss 0.03181]
# [epoch 144], [iter 20 / 25], [train loss 0.03188]
# ====================================================================
# [epoch 144], [val loss 0.06109], [acc 0.93983], [acc_cls 0.84438], [mean_iu 0.72020], [fwavacc 0.90097]
# ====================================================================
# [epoch 145], [iter 10 / 25], [train loss 0.03104]
# [epoch 145], [iter 20 / 25], [train loss 0.03132]
# ====================================================================
# [epoch 145], [val loss 0.06252], [acc 0.93784], [acc_cls 0.84231], [mean_iu 0.71458], [fwavacc 0.89855]
# ====================================================================
# [epoch 146], [iter 10 / 25], [train loss 0.03169]
# [epoch 146], [iter 20 / 25], [train loss 0.03188]
# ====================================================================
# [epoch 146], [val loss 0.06210], [acc 0.93861], [acc_cls 0.83959], [mean_iu 0.71466], [fwavacc 0.89928]
# ====================================================================
# [epoch 147], [iter 10 / 25], [train loss 0.03152]
# [epoch 147], [iter 20 / 25], [train loss 0.03150]
# ====================================================================
# [epoch 147], [val loss 0.06065], [acc 0.93980], [acc_cls 0.83382], [mean_iu 0.71288], [fwavacc 0.90037]
# ====================================================================
# [epoch 148], [iter 10 / 25], [train loss 0.03170]
# [epoch 148], [iter 20 / 25], [train loss 0.03199]
# ====================================================================
# [epoch 148], [val loss 0.06112], [acc 0.93975], [acc_cls 0.83737], [mean_iu 0.71523], [fwavacc 0.90042]
# ====================================================================
# [epoch 149], [iter 10 / 25], [train loss 0.03157]
# [epoch 149], [iter 20 / 25], [train loss 0.03186]
# ====================================================================
# [epoch 149], [val loss 0.06179], [acc 0.93918], [acc_cls 0.83919], [mean_iu 0.71438], [fwavacc 0.89998]
# ====================================================================
# [epoch 150], [iter 10 / 25], [train loss 0.03207]
# [epoch 150], [iter 20 / 25], [train loss 0.03209]
# ====================================================================
# [epoch 150], [val loss 0.06183], [acc 0.93880], [acc_cls 0.84234], [mean_iu 0.71641], [fwavacc 0.89972]
# ====================================================================

# %%
! tensorboard --logdir=writer_path --host localhost --port 8088
# Out:
# 2020-12-17 17:01:56.793448: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorBoard 2.3.0 at http://localhost:8088/ (Press CTRL+C to quit)
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/concurrent/futures/thread.py", line 33, in _python_exit
#     def _python_exit():
# KeyboardInterrupt

# %% [markdown]
# #  **Testing**

# %%
test_data_path = '/content/drive/My Drive/data/test'
test_set = TestDataset(test_data_path)
test_data_loader = DataLoader(dataset=test_set, num_workers=4, batch_size=batchsize, shuffle=False)
PATH = os.path.join(model_data_path,'Unet', 'Bestmodel_epoch_116'+'.pth')
net = UNet(num_classes = 4).cuda()
net.load_state_dict(torch.load(PATH))
net.eval()
val_loss = AverageMeter()
batchsize=4
learningrate=1e-5


# Loss function and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learningrate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)


for iteration, sample in enumerate(test_data_loader):
    img= sample
    img=img.unsqueeze(1).cuda() # adding 1 channel
    #mask=mask.to(dtype=torch.int64).cuda()# mask should be long type

    outputs = net(img)
    predictions = outputs.data.max(1)[1].squeeze_(1).squeeze_(0).cpu().numpy()
    plt.imshow(predictions[0,...],cmap='gray')
    plt.pause(0.1)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2952: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
